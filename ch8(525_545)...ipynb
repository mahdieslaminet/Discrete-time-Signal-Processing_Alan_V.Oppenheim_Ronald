# %% [markdown]
#  <div dir="rtl">
#     <h2> به نام خدا </h2>
# <div dir="rtl">
#        <h2> فصل هشت:سیستم های مخابراتی </h2>
#     <div dir="rtl">
#         <h2>استاد:دکتر مهدی اسلامی</h2>
#   <div dir="rtl">
#       <h2> نویسنده:مانیا پوررفیع </h2>
#
#
# <div dir="rtl">
# 8.0 مقدمه
#      <div dir="rtl">
#       8.1 مدولاسیون دامنه نمایی مختلط و سینوسی
#   <div dir="rtl">
#       8.1.1 مدولاسیون دامنه با حامل نمایی مختلط
#   <div dir="rtl">
#      8.1.2 مدولاسیون دامنه با حامل سینوسی
#    <div dir="rtl">
#      8.2 دمدولاسیون AM سینوسی
#    <div dir="rtl">
#      8.2.1 دمدولاسیون همزمان
#    <div dir="rtl">
#       8.2.2دمدولاسیون ناهمزمان
#   <div dir="rtl">
#      8.3 مالتی پلکس فرکانسی
#    <div dir="rtl">
#      8.4 مدولاسیون دامنه تک باند کناری
#     <div dir="rtl">
#      8.5 مدولاسیون دامنه با حامل قطار پالس
#     <div dir="rtl">
#      8.5.1 مدولاسیون حامل قطار پالس
#   <div dir="rtl">
#       8.5.2 مالتی پلکس حوزه زمان
#      <div dir="rtl">
#       8.6 مدولاسیون دامنه پالس
#     <div dir="rtl">
#       8.6.1 سیگنال مدوله شده دامنه پالس
#    <div dir="rtl">
#      8.6.2 تداخل بین نماد ها در سیستم های PAM
#     <div dir="rtl">
#      8.6.3 مدولاسیون دامنه پالس دیجیتال و کد پالسی
#     <div dir="rtl">
#      8.7 مدولاسیون فرکانس سینوسی
#     <div dir="rtl">
#      8.7.1 مدولاسیون فرکانس باریک باند
#     <div dir="rtl">
#      8.7.2 مدولاسیون فرکانس پهن باند
#      <div dir="rtl">
#      8.7.3 سیگنال مدوله کننده مربعی متناوب
#     <div dir="rtl">
#      8.8 مدولاسیون گسسته در زمان
#      <div dir="rtl">
#      8.8.1 مدولاسیون دامنه سینوسی گسسته در زمان
#      <div dir="rtl">
#       8.8.2 ترانس مدولاسیون گسسته در زمان
#
#
#
#
#
# <div dir="rtl">
#     <H2>8.0 مقدمه</H2>
# <div dir="rtl">
# سیستم‌های مخابراتی در دنیای جدید
# سیستم‌های مخابراتی در دنیای جدید نقشی کلیدی در انتقال اطلاعات بین افراد، سیستم‌ها، و کامپیوترها بازی می‌کند. به طور کلی در تمام سیستم‌های مخابراتی اطلاعات ابتدا توسط فرستنده یا مدولاتور پردازش شده، به صورتی مناسب برای ارسال بر روی کانال مخابراتی در می‌آید. سپس در گیرنده سیگنال با پردازش مناسبی بازیابی می‌شود. این پردازش به دلایلی چند لازم است. اول این که در بسیاری از موارد برای کانال مخابراتی گستره فرکانسی خاصی وجود دارد که انتقال سیگنال در آن به خوبی صورت می‌گیرد، و در خارج آن گستره انتقال نا ممکن است یا باعث افت شدید کیفیت مخابره می‌شود. مثلاً سیگنال‌های گستره شنیداری 10 تا 20 کیلوهرتز در جو به سرعت تضعیف می‌شوند، ولی سیگنال‌های گستره‌های فرکانسی بالاتر تا مسافتهای بسیار طولانی منتشر می‌شوند. پس در انتقال سیگنال‌های شنیداری چون گفتار و موسیقی در کانالی که انتقال در آن اساساً به صورت انتشار در جو صورت می‌گیرد، فرستنده ابتدا سیگنال را با پردازش مناسب به سیگنالی با فرکانس بالاتر تبدیل می‌کند.
# بسیاری از مفاهیم و روش‌های پی ریزی شده در فصول اولیه این کتاب نقش محوری در تحلیل و طراحی سیستم‌های مخابراتی دارند. مانند هر مفهوم دیگری که کاربردهای گسترده و مهمی دارد، مسائل جزیی فراوانی نیز وجود دارد که در موردشان کتاب‌های بسیار خوبی نوشته شده است و ما تعدادی از آن‌ها را در کتابنامه آخر کتاب درج کرده‌ایم. گرچه تحلیل کامل و مفصل سیستم‌های مخابراتی فراتر از حد این کتاب است، ولی با اطلاعات پایه‌ای کسب شده در فصول قبلی آماده‌ایم که اصول پایه‌ای و مباحث اصلی طراحی و تحلیل این سیستم‌ها آشنا شدیم.
# به طور کلی فرایند گنجاندن سیگنال حاوی اطلاعات در سیگنالی دیگر را مدولاسیون می‌نامند. اخذ سیگنال حاوی اطلاعات دمدولاسیون نام دارد. چنانچه خواهیم دید روش‌های مدولاسیون علاوه بر آن که امکان انتقال سیگنال را در کانال‌های مخابراتی مختلف فراهم می‌کنند، امکانات دیگری نیز برای سیستم‌های مخابراتی فراهم می‌سازند. برای مثال مدولاسیون امکان انتقال چند سیگنال را به طور همزمان بر روی یک کانال فراهم می‌سازد.
# <div dir="rtl">
# گنجاندن اطلاعات را بر روی سیگنالی که انتشار موثرتری دارد فراهم می‌کند، این امکان را نیز می‌دهد چند سیگنال دارای طیف همپوشان از طریق یک کانال انتقال یابند، این مفهوم را مالتی پلکس می‌نامند.
# روش‌های مختلفی برای مدولاسیون وجود دارد و به کار می‌رود، و در این فصل چند روش مهمتر را بررسی می‌کنیم. یک دسته بزرگ از روش‌های مدولاسیون بر مدولاسیون دامنه یا AM پایه گذاری شده‌اند، در این نوع مدولاسیون سیگنالی که قصد انتقالش را داریم دامنه سیگنال دیگری را تغییر می‌دهد. یک شکل بسیار متداول مدولاسیون دامنه مدولاسیون دامنه سینوسی است که آن را در بخش‌های 8.1 تا 8.4، به همراه مفهوم مرتبط مالتی پلکس فرکانس به تفصیل بررسی می‌کنیم. دیگر دسته مهم سیستم‌های PAM با مدولاسیون دامنه سیگنال پالسی سر و کار دارند، در بخش‌های 8-5 و 8-6 این شکل مدولاسیون را به همراه مفهوم مالتی پلکس زمانی بررسی می‌کنیم. در بخش 8.7 مدولاسیون متفاوتی موسوم به مدولاسیون فرکانس سینوسی را بررسی می‌کنیم که در آن سیگنال حاوی اطلاعات برای تغییر فرکانس یک سیگنال سینوسی به کار می‌رود.
# تا بخش 8.7 تمام تاکید بر سیگنال‌های پیوسته در زمان است، زیرا اکثر محیط‌های انتقال را بهترست سیستم‌های پیوسته در زمان به حساب آورد. ولی برای سیگنال‌های گسسته در زمان نیز می‌توان روش‌های مشابهی پی ریخت و در نظر گرفتن مفاهیم مدولاسیون چنین سیگنال‌هایی اهمیت عملی فراوانی دارد. در بخش 8.8 برخی ایده‌های مربوط به مخابرات سیگنال‌های گسسته در زمان را در نظر خواهیم گرفت.
# <div dir="rtl">
#     <H2> 8.1 مدولاسیون دامنه نمایی مختلط و سینوسی</H2>
# <div dir="rtl">
# مفهوم مدولاسیون دامنه سینوسی اساس بسیاری از سیستم‌های مخابراتی است. در این مدولاسیون دامنه یک سیگنال نمایی مختلط یا یک سیگنال سینوسی (c(t در سیگنال حاوی اطلاعات (x(t ضرب (مدوله) می‌شود. سیگنال (x(t را سیگنال مدوله کننده و سیگنال (c(t را سیگنال حامل می‌نامند. پس سیگنال مدوله شده (y(t حاصلضرب دو سیگنال است.
# $$y(t) = x(t) c(t)$$
# <div dir="rtl">
# همانطور که در بخش8.1 گفتیم هدف اصلی در مدولاسیون ایجاد سیگنالی است که گستره فرکانسی‌اش برای مخابره بر روی کانال مورد استفاده مناسب باشد. مثلاً در سیستم‌های تلفن انتقال راه دور توسط امواج میکروویو یا ماهواره‌ای صورت می‌گیرد. گستره فرکانسی صدای افراد ۲۰۰Hz تا ۴kHz است، ولی دستگاه‌های میکروویو سیگنال‌هایی در گستره ۳۰۰MHz تا ۳۰۰GHz را منتقل می‌کنند و ماهواره‌ها در گستره فرکانسی چند صد مگاهرتز تا ۴۰GHz کار می‌کنند. پس برای انتقال روی این کانال‌ها اطلاعات سیگنال گفتار باید به این فرکانس‌های بالا منتقل شود. همانطور که در این بخش می‌بینیم مدولاسیون دامنه سینوسی این انتقال فرکانسی را به روشی بسیار ساده صورت می‌دهد.
#  <div dir="rtl">
#     <H2> 8.1.1 مدولاسیون دامنه با حامل نمایی مختلط</H2>
# <div dir="rtl">
# مدولاسیون دامنه سینوسی دو شکل متداول دارد، در یکی سیگنال حامل نمایی مختلطی به شکل زیرست:
#    $$c(t) = e^{j(\omega_c t + \theta_c)}  \qquad(8.1)$$
#    <div dir="rtl">
#    و در دیگری سیگنال حامل سینوسی و به صورت زیر است
#    $$c(t) = \cos(\omega_c t + \theta_c)\qquad (8.2) $$
#
#   <div dir="rtl">
#    در هر دو صورت فرکانس $\omega_c$ را فرکانس حامل می‌نامند. ابتدا شکل اول را در نظر می‌گیریم و برای سهولت فرض می‌کنیم $\theta_c = 0$ تا سیگنال مدوله شده $y(t)$ به صورت زیر باشد:
#   $$y(t) = x(t) e^{j\omega_c t}\qquad (8.3) $$
#
# <div dir="rtl">
# طبق خاصیت ضرب (بخش4.5) و با نشان دادن تبدیل فوریه $x(t)$، $y(t)$ و $c(t)$ با $X(j\omega)$، $Y(j\omega)$ و $C(j\omega)$ داریم:
#
# \begin{equation}
# Y(j\omega) = \frac{1}{2\pi} X(j\omega) * C(j\omega) \tag{8.4}
# \end{equation}
# <div dir="rtl">
# اگر $c(t)$ سیگنال نمایی مختلط معادله (8.1) باشد، آنگاه:
#
# \begin{equation}
# C(j\omega) = 2\pi\delta(\omega - \omega_c) \tag{8.5}
# \end{equation}
# <div dir="rtl">
# پس:
#
# \begin{equation}
# Y(j\omega) = X(j\omega - j\omega_c) \tag{8.6}
# \end{equation}
# <div dir="rtl">
# بنابراین طیف خروجی مدوله شده $y(t)$ همان طیف ورودی است که به اندازه فرکانس حامل $\omega_c$ انتقال جابجا شده است. مثلاً اگر مطابق شکل 8.1 (الف) $X(j\omega)$ محدود باند و بالاترین فرکانس آن $\omega_M$ باشد (یعنی پهنای باند آن $2\omega_M$ باشد)، طیف خروجی $Y(j\omega)$ به صورت شکل 8.1 (ج) است.
# <div dir="rtl">
# از معادله (8.3) پیداست که می‌توان $x(t)$ را با ضرب $y(t)$ در نمایی مختلط $e^{-j\omega_c t}$ از سیگنال مدوله شده بدست آورد.
# <div dir="rtl">
#
# \begin{equation}
# x(t) = y(t) e^{-j\omega_c t} \tag{8.7}
# \end{equation}
# <div dir="rtl">
# این کار در حوزه فرکانس معادل انتقال طیف سیگنال مدوله شده به عقب و در محل اولیه خودش است. فرایند بازیابی سیگنال اصلی از سیگنال مدوله شده را دمدولاسیون می‌نامند. این موضوع را در بخش 8.2 دنبال خواهیم کرد.
# <div dir="rtl">
# چون $e^{j\omega_c t}$ سیگنال مختلطی است، معادله (8.3) را می‌توان به صورت زیر بازنویسی کرد:
#
# \begin{equation}
# y(t) = x(t) \cos \omega_c t + jx(t) \sin \omega_c t \tag{8.7}
# \end{equation}
# <div dir="rtl">
# ساختن معادله (8.7) یا (8.8) با $x(t)$ حقیقی دو ضرب کننده و دو سیگنال حامل سینوسی با اختلاف فاز $\frac{\pi}{2}$ به ازای $c(t)$ معادله (8.1) نشان داده شده است. در بخش 8.4 کاربرد نمونه‌ای را معرفی می‌کنیم که در آن به کاربردن سیستمی مانند شکل 8.2، با دو حامل سینوسی دارای اختلاف فاز $\frac{\pi}{2}$، مزایایی به همراه دارد.
# <div dir="rtl">
#     <h2> 8.1.2 مدولاسیون دامنه با حامل سینوسی</H2>
# <div dir="rtl">
#   در وضعیتهای بسیاری استفاده از حامل سینوسی به صورت معادله (8.2) ساده‌تر و به همان کارآمدی حامل نمایی مختلط است. در واقع استفاده از حامل سینوسی معادل این است که در شکل 8.2 تنها یکی از بخش‌های حقیقی یا موهومی خروجی را نگه داریم. شکل 8.3 سیستمی با حامل سینوسی را نشان می‌دهد.
# اثر مدولاسیون دامنه با حامل سینوسی به صورت معادله (8.2) را می‌توان با روشی مشابه روش بالا تحلیل کرد. بار دیگر برای سهولت فرض می‌کنیم $\theta_c = 0$. در این صورت طیف سیگنال حامل عبارت است از:
# <div dir="rtl">
# از:
#
# \begin{equation}
# C(j\omega) = \pi [\delta(\omega - \omega_c) + \delta(\omega + \omega_c)] \tag{8.9}
# \end{equation}
# <div dir="rtl">
# و بنابراین طبق معادله (7.4) داریم:
#
# \begin{equation}
# Y(j\omega) = \frac{1}{2} [X(j\omega - j\omega_c) + X(j\omega + j\omega_c)] \tag{8.10}
# \end{equation}
#
#
# <div dir="rtl">
# به ازای $X(j\omega)$ شکل 8.1 (الف)، طیف $y(t)$ به صورت شکل 8.1 (ج) است. توجه کنید که در این حالت هم:
# حول $\omega_c$ و $-\omega_c$ گونه‌ای از طیف سیگنال اصلی وجود دارد. پس تنها به شرطی می‌توان $x(t)$ را از $y(t)$ بازیابی کرد که $\omega_c < \omega_M$، زیرا در غیر این صورت دو طیف روی هم می‌افتند. در مورد حامل نمایی مختلط که تنها یک نمونه طیف حول $\omega_c$ قرار می‌گیرد چنین نیست. در واقع چنانچه در بخش 8.1.1 دیدیم در مدولاسیون دامنه با حامل نمایی مختلط همیشه می‌توان $x(t)$ را از $y(t)$ به ازای هر مقدار $\omega_c$ بازیافت، به این منظور باید طیف را با ضرب در $e^{-j\omega_c t}$ مطابق معادله (8.7) به محل اصلی‌اش برگرداند. ولی برای حامل سینوسی، چنانچه شکل 8.4 نشان می‌دهد، به ازای $\omega_c < \omega_M$ دو نمونه طیف $X(j\omega)$ روی هم می‌افتند. شکل 8.5 $Y(j\omega)$ را به ازای $\omega_c = \omega_M / 2$ نشان می‌دهد. واضح است که تکرار طیف $x(t)$ در $Y(j\omega)$ مشاهده نمی‌شود. بنابراین نمی‌توان $x(t)$ را از $y(t)$ به دست آورد.
# <div dir="rtl">
#     <h2> دمدولاسیون AM سینوسی</h2>
# <div dir="rtl">
#  در گیرنده، سیگنال حاوی اطلاعات $x(t)$ توسط فرایند دمدولاسیون بازیابی می شود. در این بخش فرایند دمدولاسیون را برای مدولاسیون دامنه سینوسی معرفی شده در بخش پیش بررسی می کنیم. برای دمدولاسیون دو روش متداول وجود دارد که هر کدام مزایا و معایب خودشان را دارند. روش اول را در بخش 8.2.1 مورد بحث قرار می دهیم. این فرایند را **دمدولاسیون همزمان** می نامند و در آن فرستنده و گیرنده از لحاظ فاز همزمان می شوند. در بخش 8.2.2 روش دیگری مرسوم به **دمدولاسیون ناهمزمان** را معرفی می کنیم.
# <div dir="rtl">
# <h2> 8.2.1 دمدولاسیون همزمان</h2>
# <div dir="rtl">
# دمدولاسیون سیگنالی که با حامل سینوسی مدوله شده است به ازای $\omega_M < \omega_c$ به روشی سر راست صورت می‌گیرد. سیگنال زیر را در نظر بگیرید:
#
# \begin{equation}
# y(t) = x(t) \cos \omega_c t \tag{8.11}
# \end{equation}
# <div dir="rtl">
# چنان که از مثال 4.23 بر می‌آید، با مدولاسیون y(t) با همان حامل سینوسی و گذراندن سیگنال حاصل از فیلتر پایین گذر می‌توان سیگنال اصلی را به دست آورد. برای پی بردن به این مطلب فرض کنید:
#
# \begin{equation}
# w(t) = y(t) \cos \omega_c t \tag{8.12}
# \end{equation}
# <div dir="rtl">
# شکل 8.6 طیف $y(t)$ و $w(t)$ را نشان می‌دهد و می‌بینیم که با به کار بردن یک فیلتر پایین گذر ایده‌آل با بهره 2 و فرکانس قطع بزرگتر از $\omega_M$ و کوچکتر از $2\omega_c - \omega_M$، می‌توان $x(t)$ را از $w(t)$ بازیافت. پاسخ فرکانسی فیلتر پایین گذر در شکل 8.6 (ج) با خط چین نشان داده شده است.
# <div dir="rtl">
#     مبنای استفاده از معادله8.12 و فیلتر پایین گذر برای دمدولاسیون y(t) را می توان به روش جبری زیر نشان داد.از معادله های 8.11 و 8.12 نتیجه می شود که:
# $$w(t) = x(t) \cos^2 \omega_c t$$
#
# <div dir="rtl">
#     با استفاده از اتحاد مثلثاتی زیر
#    $$\cos^2 \omega_c t = \frac{1}{2} + \frac{1}{2} \cos 2\omega_c t $$
#
#   <div dir="rtl">
# می توان w(t)را به این صورت نوشت
#
# $$w(t) = \frac{1}{2} x(t) + \frac{1}{2} x(t) \cos 2\omega_c t  \qquad(8.13) $$
# <div dir="rtl">
# بنابراین $w(t)$ مجموع دو جمله است، یکی نصف سیگنال اصلی و دیگری هم نصف سیگنال اصلی که توسط حاملی با فرکانس $2\omega_c$ مدوله شده باشد. هر دو جمله در طیف شکل (8.6 (ج)) مشخص شده اند. به کار بردن فیلتر پایین گذر برای $w(t)$ با نگه داشتن جمله اول سمت راست معادله (8.13) و حذف جمله دوم آن، متناظر است.
# <div dir="rtl">
# شکل 8.7 سیستم مدولاسیون و دمدولاسیون دامنه با حامل نمایی مختلط و شکل 8.8 سیستم مدولاسیون و دمدولاسیون با حامل سینوسی را نشان می‌دهد. در این شکلها حالت کلی تری را نشان داده‌ایم که در آن هر حامل نمایی مختلط و سینوسی دارای فاز $\theta_c$ هستند. اصلاح تحلیل پیش برای منظور کردن $\theta_c$ سر راست است و در مسئله 8.21 بررسی می‌شود.
# <div dir="rtl">
# در سیستم‌های شکل‌های8.7 و 8.8 فرض شده است که سیگنال دمدولاسیون از لحاظ فاز با سیگنال مدوله کننده همزمان است؛ به همین دلیل این فرایند را دمدولاسیون همزمان می‌نامند. ولی اکنون فرض کنید مدولاتور و دمدولاتور همزمان نیستند. برای حامل نمایی مختلط اگر فاز حامل مدوله کننده $\theta_c$ و فاز حامل دمدوله کننده $\theta_c$ باشد، داریم:
#
# $$
# \begin{aligned}
# y(t) &= e^{j(\omega_c t + \theta_c)} x(t) \qquad(8.14)\\
# w(t) &= e^{j(\omega_c t + \phi_c)} y(t) \qquad(8.15)
# \end{aligned}
# $$
#
# <div dir="rtl">
#     و در نتیجه
#     $$w(t) = e^{j(\theta_c - \phi_c)} x(t) \qquad(8.16) $$
#  <div dir="rtl">
#     پس به ازای $\theta_c \neq \phi_c$، $w(t)$ یک ضریب مختلط دارد. برای حالت خاصی که $x(t)$ مثبت است، $|w(t)| = x(t)$. و بنابراین $x(t)$ را می‌توان با گرفتن اندازه سیگنال دمدوله شده به دست آورد.
#  <div dir="rtl">
# برای حامل سینوسی فاز حاملهای مدوله کننده و مدوله کننده را مطابق شکل 9.8 به ترتیب با $\theta_c$ و $\phi_c$ نشان می‌دهیم. اکنون ورودی فیلتر پایین گذر عبارت است از:
#
#  $$w(t) = x(t) \cos(\omega_c t + \theta_c) \cos(\omega_c t + \phi_c) \quad (8.17)$$
#
# <div dir="rtl">
#   و با استفاده از اتحاد مثلثاتی
#
#   $$\cos(\omega_c t + \theta_c) \cos(\omega_c t + \phi_c) = \frac{1}{2} \cos(\theta_c - \phi_c) + \frac{1}{2} \cos(2\omega_c t + \theta_c + \phi_c) \quad (8.18)$$
#
#   <div dir="rtl">
#      بدست می اوریم:
#  $$w(t) = \frac{1}{2} \cos(\theta_c - \phi_c) x(t) + \frac{1}{2} x(t) \cos(2\omega_c t + \theta_c + \phi_c) \quad (8.19)$$
#
#   <div dir="rtl">
#      و در این صورت خروجی فیلتر پایین گذر حاصل ضرب $x(t)$ و ضریب دامنه $\cos(\theta_c - \phi_c)$ است. اگر نوسانسازهای مدوله کننده و دمدوله کننده همفاز باشند، $\theta_c = \phi_c$، و خروجی فیلتر پایین گذر $x(t)$ است. برعکس، اگر اختلاف فاز نوسانسازها $\pi/2$ باشد، خروجی صفر است. به طور کلی برای ماکزیمم بودن سیگنال خروجی، نوسانسازها باید همفاز باشند. مهمتر این است که رابطه فاز دو نوسانساز باید ثابت بماند تا ضریب دامنه $\cos(\theta_c - \phi_c)$ تغییر نکند. این امر مستلزم همزمانی دقیق نوسانسازهای مدوله کننده و دمدوله کننده است، امری که در عمل، مخصوصاً هنگامی که سیستمهای مدوله کننده و دمدوله کننده دور از هم قرار دارند، کاری مشکل است. اثرهای این همزمانی و نیاز به همزمانی فرکانسی مدولاتور و دمدولاتور، علاوه بر همزمانی فاز، در مسئله 8.23 به تفصیل بررسی خواهد شد.
#
#
#
#
#
#
#
#
#
#
#
# <div dir="rtl">
# <h2> 8.2.2دمدولاسیون ناهمزمان</h2>
# <div dir="rtl">
# در بسیاری از سیستم‌های مدولاسیون دامنه سینوسی روند دمدولاسیون دیگری موسوم به دمدولاسیون ناهمزمان به کار می‌رود که در آن هم‌زمانی مدوله کننده و دمدوله‌ کننده لازم نیست. فرض کنید $x(t)$ همیشه مثبت و فرکانس حامل $\omega_c$ (یعنی بزرگترین فرکانس سیگنال مدوله کننده) خیلی بزرگترست. در این صورت شکل کلی سیگنال مدوله شده $y(t)$ (مطابق شکل 8.10) است. پوش $y(t)$، یعنی منحنی همواری که قله‌های $y(t)$ را به هم وصل می‌کند، تقریب قابل قبولی از $x(t)$ است، بنابراین با استفاده از سیستمی که برای استخراج پوش این قله‌ها را دنبال کند، می‌توان $y(t)$ را تقریباً بازیابی کرد. چنین سیستمی را آشکارسازپوش می‌نامند. در شکل 8.11 (الف) یک مدار ساده نشان داده شده است که به صورت آشکارساز پوش عمل می‌کند. معمولاً بعد از این مدار یک فیلتر پایین‌گذر گذاشته می‌شود تا تموج‌هایی که مطابق شکل 8.11 (ب) در خروجی آشکارساز پوش وجود دارد حذف شود
# <div dir="rtl">
# دو فرض اساسی لازم برای دمدولاسیون ناهمزمان این است که $x(t)$ مثبت باشد و در مقایسه با $\omega_c$ آهسته تغییر کند تا بتوان پوش را به آسانی دنبال کرد. مثلاً در انتقال سیگنال‌های شنیداری در کانال فرکانس رادیویی (RF)، که بزرگترین فرکانس موجود در $m(t)$ نوعاً 20kHz تا 15kHz و $\omega_c/2\pi$ در گستره $2MHz$ تا $5۰۰kHz$ است، شرط دوم برآورده می‌شود. شرط اول، یعنی مثبت بودن $s(t)$ را می‌توان با افزودن مقدار ثابت مناسبی به $m(t)$، یا تغییر ساده مدوله کننده به صورت شکل 8.12 برآورده کرد. در این صورت خروجی آشکارساز پوش تقریبی از $A+x(t)$ است و $x(t)$ را به آسانی می‌توان از آن به دست آورد.
# در استفاده از آشکارسازپوش برای دمدولاسیون باید $A$ آنقدر بزرگ باشد که $A+x(t)$ همیشه مثبت باشد. فرض کنید $K$ ماکزیمم دامنه $|x(t)|$ است، یعنی $|x(t)| \leq K$. برای مثبت بودن $A+x(t)$ باید داشته باشیم $A > K$. را شاخص مدولاسیون $m$ می‌نامند. بیان این نسبت بر حسب درصد، درصد مدولاسیون نام دارد. در شکل 8.13 خروجی مدوله کننده شکل 8.12 به ازای $m = ۰/5$ (مدولاسیون سینوسی) و $m = 1$ (مدولاسیون 100\%) نشان داده شده است.
# <div dir="rtl">
# در شکل 8.14 طیف‌های مربوط به سیگنال مدوله شده با استفاده از دمدولاسیون همزمان و دمدولاسیون ناهمزمان مقایسه شده‌اند. مخصوصاً توجه کنید که خروجی مدوله کننده ناهمزمان شکل 8.12 یک مؤلفه اضافی $\cos \omega_c t$ دارد که در سیستم همزمان نه وجود دارد و نه وجودش لازم است. این مؤلفه در طیف شکل 8.14 (ج) به صورت ضربه‌هایی در $+\omega_c$ و $-\omega_c$ نشان داده شده است. اگر ماکزیمم دامنه سیگنال مدوله کننده $K$ باشد، با کاهش $K$ شاخص مدولاسیون افزایش و مقدار نسبی حامل موجود در خروجی مدوله شده کاهش می‌یابد. چون مؤلفه حامل موجود در خروجی حاوی اطلاعات نیست، حضور آن کاهش بازده (مثلاً از لحاظ توان لازم برای انتقال سیگنال مدوله شده) را نشان می‌دهد و در نتیجه بهترست تا می‌توانیم شاخص مدولاسیون را بزرگ کنیم. از طرف دیگر هر چه شاخص مدولاسیون کوچکتر شود، توانایی آشکارسازپوش ساده‌ای مثل آشکارساز شکل 8.11 در دنبال کردن پوش و بیرون کشیدن $x(t)$ بهتر می‌شود. بنابراین بین بازده سیستم از لحاظ توان خروجی مدولاتور و کیفیت سیگنال دمدوله شده باید مصالحه‌ای صورت گیرد.
# <div dir="rtl">
# سیستم مدولاسیون – دمدولاسیون ناهمزمان شکلهای 8.11 و 8.12 در مقایسه با سیستم همزمان شکل 8.8 مزایا و معایبی دارد. سیستم همزمان دمدولاتور پیچیده‌تری نیاز دارد، زیرا نوسانساز آن باید از لحاظ فرکانس و فاز با نوسانساز مدولاتور همزمان باشد. از طرف دیگر مدولاتور ناهمزمان برای ارسال توان بیشتری می‌خواهد، زیرا برای درست کار کردن آشکارساز پوش، پوش باید مثبت باشد، یا به عبارت دیگر در سیگنال ارسالی باید مؤلفه حامل نیز وجود داشته باشد. این روش غالباً در مواردی چون پخش رادیو ترجیح داده می‌شود، زیرا گیرنده‌ها (دمدولاتورها) متعددند و باید هزینه ساختمان کم باشد. هزینه اضافی ناشی از توان اضافی با صرفه جویی صورت گرفته در گیرنده‌ها جبران می‌شود. ولی در مواردی که توان ارسالی در درجه اول اهمیت قرار دارد، مثل مخابره ماهواره‌ای، هزینه ساخت گیرنده‌های همزمان پیچیده‌تر توجیه پذیرست.
# <div dir="rtl">
# <h2> 8.3 مالتی پلکس در فرکانسی</h2>
# <div dir="rtl">
# بسیاری از سیستم‌هایی که برای انتقال سیگنال به کار می‌روند پهنای باندشان از پهنای باند لازم برای انتقال یک سیگنال بزرگترست. برای مثال پهنای باند یک رابط میکروویو چند گیگاهرتزست، این پهنای باند از مقدار لازم برای انتقال یک کانال صدا بسیار بزرگترست. اگر با مدولاسیون دامنه سینوسی سیگنالهای صدا، که طیفشان همپوشانی دارد، به فرکانسهای بالاتر منتقل شوند به نحوی که طیف سیگنالهای مدوله شده همپوشانی نداشته باشند، می‌توان آنها را به طور همزمان روی یک کانال مخابره کرد. این مفهوم را مالتی پلکس فرکانسی (FDM) می‌نامند. شکل8.15 چگونگی مالتی پلکس با حامل سینوسی را نشان می‌دهد. سیگنالهای مدوله شده با هم جمع شده، به طور همزمان، روی یک کانال ارسال می‌شود. شکل 8.16 طیف کانالها و سیگنال مالتی پلکس شده مرکب را نشان می‌دهد. در این فرایند سپس هر سیگنال ورودی به بخش فرکانسی مجزایی منتقل می‌شود. برای بازیابی هر سیگنال در فرایند دی مالتی پلکس دو گام اساسی لازم است: عبور از فیلتر میان‌گذر برای استخراج سیگنال مدوله شده کانال مورد نظر، و دمدولاسیون برای بازیابی سیگنال اصلی. این فرایند در شکل 8.17 برای بازیابی کانال $a$ نشان داده شده است. مدولاسیون همزمان فرض شده است.
# <div dir="rtl">
# مخابرات تلفنی یکی از کاربردهای مهم مالتی پلکس فرکانسی است. ارسال سیگنال از طریق جو در باند فرکانس رادیویی (RF) یک نمونه دیگرست. در ایالات متحده استفاده از فرکانسهای رادیویی برای ارسال سیگنال در گستره 10kHz تا 275GHz توسط کمیسیون مخابرات فدرال کنترل می‌شود و بخشهای مختلف این گستره فرکانسی به منظورهای مختلف اختصاص یافته است. شکل 8.18 تقسیم بندی فعلی را نشان می‌دهد. مطابق این شکل گستره فرکانسی حول 1MHz به بخش AM اختصاص یافته است، منظور از AM مدولاسیون دامنه سینوسی است. به هر یک از ایستگاههای رادیویی فرکانسهای خاصی از باندAM اختصاص داده شده است و بنابراین چندین ایستگاه می‌توانند به خاطر این مالتی پلکس فرکانسی به طور
# <div dir="rtl">
# همزمان برنامه پخش کنند. در گیرنده می‌توان به صورت نشان داده شده در شکل 8.17با دی مالتی پلکس و دمدولاسیون هر یک از ایستگاههای رادیویی را برگزید. پیچ تنظیم گیرنده هم فرکانس میانی فیلتر میان گذر و هم فرکانس نوسانساز دمدولاتور را کنترل می‌کند. در واقع در بخش رادیویی از مدولاسیون و دمدولاسیون ناهمزمان استفاده می‌شود تا گیرنده ساده و ارزان باشد. به علاوه دی مالتی پلکس شکل 8.17 به یک فیلتر میان‌گذر نیز با فرکانس میانی متغیر نیاز دارد. ساخت فیلترهای فرکانس گزین متغیر مشکل است و به همین دلیل یک فیلتر ثابت و یک طبقه میانی، متشکل از یک سیستم مدولاسیون و یک فیلتر، به کار می‌رود [که در گیرنده رادیو آن را طبقه فرکانس میانی (IF) می‌نامند]. کاربرد دمدولاسیون برای لغزاندن طیف در مقابل یک فیلتر میان‌گذر ثابت، که به جای فیلتر میان‌گذر متغیر به کار می‌رود، شبیه روشی است که در بخش 1.5 مورد بحث قرار گرفت. این کار در رادیوهای خانگی انجام می‌شود. برخی جزییات مربوط به این روش در مثال 8.36 در نظر گرفته شده است.
# <div dir="rtl">
# <h2>8.4 مدولاسیون دامنه تک باند کناری</h2>
# <div dir="rtl">
# در سیستم‌های مدولاسیون دامنه مورد بحث در بخش 8.1 پهنای باند کلی سیگنال $x(t)$ با در نظر گرفتن فرکانسهای مثبت و منفی $\omega_M$ است حال آنکه بالاترین فرکانس موجود در $x(t)$، $\omega_M$ است. با استفاده از حامل نمایی مختلط این طیف به حول $\omega_c$ منتقل می‌شود و پهنای باندی که در آن انرژی وجود دارد همچنان $2\omega_M$ است، البته سیگنال مدوله شده مختلط است. ولی با حامل سینوسی، طیف سیگنال هم به $+\omega_c$ و هم به $-\omega_c$ منتقل، و در نتیجه پهنای باند دو برابر می‌شود. پس در سیگنال مدوله شده با حامل سینوسی اطلاعات زائد وجود دارد. با استفاده از روشی موسوم به مدولاسیون تک کنار باندی می‌توان این اطلاعات زائد را حذف کرد.
# <div dir="rtl">
# طیف $X(t)$ در شکل 8.19 (الف) نشان داده شده و آن مؤلفه‌های فرکانسی مثبت و منفی به نحو متفاوتی هاشور زده شده تا از هم متمایز شوند. شکل 8.19 (ب) طیف حاصل از مدولاسیون با حامل سینوسی است و می‌بینیم که بخشهای حول $+\omega_c$ و $-\omega_c$ یک کنار باند بالا و یک کنار باند پایین دارند. مقایسه شکلهای 8.19 (الف) و (ب) نشان می‌دهد که اگر تنها کنار باندهای بالا (یا تنها کنار باندهای پایین) را نگه داریم، باز هم می‌توانیم $X(\omega)$ را به دست آوریم. اگر تنها کنار باندهای بالا نگه داشته شوند، طیف شکل 9.18(ج)، و اگر تنها کنار باندهای پایین نگه داشته شوند طیف شکل 9.18 (د) به دست می‌آید. تبدیل $X(t)$ به صورتی که طیف آن متناظر با شکل 8.19 (ج) یا (د) به دست آید مدولاسیون تک کنار باندی (SSB) نامیده می‌شود، در مقابل طیف شکل 8.19 (ب) که در آن هر دو کنار باند حفظ شده است ومدولاسیون دو کنار باندی (DSB)
# نامیده می شود.
#
# <div dir="rtl">
# برای به دست آوردن سیگنال تک کنار باندی روشهای متعددی وجود دارد. یک روش که در شکل 9.25 نشان داده شده، اعمال فیلتر تیز بالاگذر با میان‌گذر به سیگنال دو کنار باندی شکل 9.19 (ب) است، تا کنار باند ناخواسته حذف شود. در روش دوم از تغییر دهنده‌ی فاز استفاده می‌شود. شکل 8.21 سیستمی را نشان می‌دهد که برای حفظ کنار باندهای پایین طراحی شده است. سیستم $H(j\omega)$ یک «شبکه تغییر فاز 90°» است که پاسخ فرکانسی آن عبارت است از:
# <div dir="rtl">
# $$H(j\omega) = \begin{cases} -j, & \omega > 0 \\ j, & \omega < 0 \end{cases}\quad $$  (8.20)
# <div dir="rtl">
# طیفهای $y_1(t) = x(t) \cos \omega_c t$ و $y_2(t) = x_p(t) \sin \omega_c t$ در شکل 8.22 نشان داده شده است. در مسئله 8.28 خواهیم دید که برای نگه داشتن کنار باندهای بالا باید مشخصه فاز $H(j\omega)$ برعکس شود:
# <div dir="rtl">
# $$H(j\omega) = \begin{cases} j, & \omega > 0 \\ -j, & \omega < 0 \end{cases} \quad$$ (8.21)
# <div dir="rtl">
# در مسئله 8.29 خواهیم دید که دمدولاسیون همزمان سیستم‌های تک کنار باندی مانند دمدولاسیون همزمان سیستم دو کنار باندی انجام می شود. بهای این افزایش کارآیی سیستم‌های تک کنار باندی، پیچیدگی بیشتر مدوله کننده است.
# <div dir="rtl">
# به طور خلاصه در بخشهای8.1 تا 8.4 چند نوع مدولاسیون دامنه نمایی مختلط و سینوسی بررسی کردیم. در دمدولاسیون ناهمزمان مورد بحث در بخش 8.2 باید مقدار ثابتی با سیگنال مدوله کننده اضافه شود تا سیگنال حاصل همیشه مثبت باشد. این امر باعث می‌شود سیگنال حامل به عنوان مولفه‌ای در خروجی مدوله شده ظاهر شود، بنابراین برای ارسال آن توان بیشتری لازم است. ولی در عوض دمدولاتور ساده‌تر از سیستم همزمان می‌طلبد. همچنین می‌توان تنها کنار باندهای بالا یا پایین خروجی مدوله شده را نگه داشت، تا از پهنای باند و توان بهتر استفاده شود، ولی این کار مدولاتوری پیچیده‌تر می‌خواهد. مدولاسیون دامنه سینوسی دو کنار باندی را به اختصار AM-DSB/WC (مدولاسیون دامنه دو کنار باندی/حامل دار) و بدون حامل را به اختصار AM-DSB/SC (مدولاسیون دامنه دو کنار باندی-حامل محذوف) می‌نامند. سیستم‌های متناظر تک کنار باندی به اختصار AM-SSB/WS و AM-SSB/SC نامیده می‌شوند.
# <div dir="rtl">
# هدف بخشهای 8.1 تا 8.4 معرفی مفاهیم اساسی مدولاسیون دامنه بود. جزییات سیستم و روشهای ساخت تنوع زیادی دارند و خواننده را به کتابهای عالی بسیاری که این موضوع را بیشتر می‌شکافند، و در کتابنامه نامبرده شده‌اند، رجوع می‌دهیم.

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_signal_flow_networkx(x_label, cos_label, y_label):
    """
    نمایش نمودار جریان سیگنال با استفاده از NetworkX.
    """
    G = nx.DiGraph()  # نمودار جهت‌دار

    # گره‌ها
    G.add_node('x', pos=(0, 0))
    G.add_node('sum', pos=(3, 0))
    G.add_node('cos', pos=(3, 2))
    G.add_node('y', pos=(5, 0))

    # یال‌ها
    G.add_edge('x', 'sum')
    G.add_edge('cos', 'sum')
    G.add_edge('sum', 'y')

    pos = nx.get_node_attributes(G, 'pos')
    labels = {
        'x': x_label,
        'sum': 'X',
        'cos': cos_label,
        'y': y_label
    }

    nx.draw(G, pos, with_labels=True, labels=labels, node_size=2000, node_color='gray', arrowsize=20)
    plt.show()

# استفاده از تابع برای رسم شکل
draw_signal_flow_networkx('x(t)', r'cos($\omega_c t + \theta_c$)', 'y(t)')

# %% [markdown]
# مدولاسیون دامنه با حامل سینوسی

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_modulated_signal_with_envelope():
    """
    نمایش سیگنال مدوله شده با پوش آن.
    """
    t = np.linspace(0, 10, 1000)  # بازه زمانی
    carrier_frequency = 5  # فرکانس حامل
    modulation_frequency = 1  # فرکانس مدولاسیون
    modulation_index = 0.8  # ضریب مدولاسیون

    # سیگنال مدوله شده
    modulated_signal = (1 + modulation_index * np.sin(2 * np.pi * modulation_frequency * t)) * np.sin(2 * np.pi * carrier_frequency * t)

    # پوش بالا و پایین
    upper_envelope = (1 + modulation_index * np.sin(2 * np.pi * modulation_frequency * t))
    lower_envelope = -(1 + modulation_index * np.sin(2 * np.pi * modulation_frequency * t))

    plt.figure(figsize=(12, 6))
    plt.plot(t, modulated_signal, 'k-', label='سیگنال مدوله شده')
    plt.plot(t, upper_envelope, 'r--', label='شوپ')
    plt.plot(t, lower_envelope, 'r--')

    # خط عمودی در مرکز
    plt.axvline(x=5, color='k', linestyle='-')

    plt.xlabel('زمان (ثانیه)')
    plt.ylabel('مقدار سیگنال')
    plt.title('Push-pull modulated signal')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_modulated_signal_with_envelope()

# %% [markdown]
# یک سیگنال مدوله شده دامنه که سیگنال مدوله کننده مثبت است.

# %%
import numpy as np
import matplotlib.pyplot as plt

# موقعیت‌های دو ضربه
omega_c = 5
positions = [-omega_c, omega_c]
amplitudes = [np.pi, np.pi]

# رسم شکل
plt.figure(figsize=(8, 3))
plt.axhline(0, color='BLACK', linewidth=1)  # محور افقی
plt.axvline(0, color='BLACK', linewidth=1)  # محور عمودی

# رسم ضربه‌ها
for x, h in zip(positions, amplitudes):
    plt.arrow(x, 0, 0, h, head_width=0.3, head_length=0.5, fc='GRAY', ec='GRAY', linewidth=2)
    plt.text(x, h + 0.2, r'$\pi$', ha='center', fontsize=14)

# تنظیمات نمودار
plt.xlim(-2*omega_c, 2*omega_c)
plt.ylim(0, max(amplitudes) + 1)
plt.xticks(positions, [r'$-\omega_c$', r'$\omega_c$'])
plt.xlabel(r'$\omega$', fontsize=14)
plt.ylabel(r'$C(j\omega)$', fontsize=14)
plt.title('Spectral representation including two impulse functions', fontsize=13)
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# شکل 8.12
# حامل سینوسی حوزه فرکانسی

# %%
import numpy as np
import matplotlib.pyplot as plt

# تعریف محور زمان
t = np.linspace(-5, 5, 1000)

# تعریف پوش‌تابی (envelope) — مثلاً گاوسی یا ضربی (sinc-like)
envelope = np.exp(-t**2)

# سیگنال سینوسی (موج حامل)
carrier = np.cos(10 * np.pi * t)

# سیگنال مدوله شده
signal = envelope * carrier

# رسم نمودار
plt.figure(figsize=(10, 4))
plt.plot(t, signal, color='yellow', linewidth=2, label='Modulated Signal')

# رسم پوش بالا و پایین
plt.plot(t, envelope, 'k--', linewidth=1)
plt.plot(t, -envelope, 'k--', linewidth=1)

# محور و برچسب‌ها
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.xlabel("t", fontsize=14)
plt.title("Modulated signal", fontsize=14)
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# شکل 8.13
# خروجی سیستم مدولاسیون دامنه به ازای شاخص 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# تعریف دامنه فرکانسی
omega = np.linspace(-10, 10, 1000)

# مرکز پالس و پهنای آن
omega_c = 2  # حداکثر مقدار ω برای مثلث
X = np.where(np.abs(omega) <= omega_c, 1 - np.abs(omega)/omega_c, 0)

# رسم نمودار
plt.figure(figsize=(8, 3))
plt.plot(omega, X, color='BLUE', linewidth=2)

# رسم محورهای مختصات
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# برچسب‌ها
plt.text(0, 1.05, '1', ha='center', fontsize=12)
plt.xlabel(r'$\omega$', fontsize=14)
plt.ylabel(r'$X(j\omega)$', fontsize=14)

# تنظیمات نمودار
plt.ylim(-0.1, 1.2)
plt.title('Triangular function in the frequency domain', fontsize=13)
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# پارامترها
omega_c = 4
width = 2
height = 0.5
omega = np.linspace(-10, 10, 1000)
X = np.zeros_like(omega)

# تابع پالس مثلثی
def triangle_pulse(center, width, height):
    slope = height / width
    return np.maximum(0, height - slope * np.abs(omega - center))

# جمع دو پالس مثلثی حول ±ω_c
X += triangle_pulse(omega_c, width, height)
X += triangle_pulse(-omega_c, width, height)

# ترسیم
plt.figure(figsize=(10, 4))
plt.plot(omega, X, color='purple', linewidth=2)

# محورهای پررنگ
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=2)

# برچسب‌ها
plt.text(0.2, 0.55, r'$\frac{1}{2}$', fontsize=13)
plt.text(omega_c - 0.5, -0.08, r'$\omega_c$', fontsize=13)
plt.text(-omega_c - 0.7, -0.08, r'$-\omega_c$', fontsize=13)
plt.text(9, 0.6, r'$X(j\omega)$', fontsize=14)
plt.xlabel(r'$\omega$', fontsize=14)

# تنظیمات گرافیکی
plt.ylim(-0.2, 0.7)
plt.yticks([])
plt.grid(False)
plt.title('Double Triangular Spectrum $X(j\\omega)$')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# پارامترها
omega_c = 4
width = 2
A = 1
height = 0.5
omega = np.linspace(-10, 10, 1000)
X = np.zeros_like(omega)

# تابع پالس مثلثی
def triangle_pulse(center, width, height):
    slope = height / width
    return np.maximum(0, height - slope * np.abs(omega - center))

# ساخت پالس‌های مثلثی
X += triangle_pulse(omega_c, width, height)
X += triangle_pulse(-omega_c, width, height)

# ترسیم نمودار
plt.figure(figsize=(10, 4))
plt.plot(omega, X, color='GREEN', linewidth=2)

# اضافه کردن ضربه‌ها به صورت فلش از محور افقی
plt.annotate('', xy=(omega_c, np.pi*A), xytext=(omega_c, 0),
             arrowprops=dict(facecolor='BLACK', width=2, headwidth=8))
plt.annotate('', xy=(-omega_c, np.pi*A), xytext=(-omega_c, 0),
             arrowprops=dict(facecolor='BLACK', width=2, headwidth=8))

# برچسب‌ها
plt.text(omega_c - 0.2, np.pi*A + 0.1, r'$\pi A$', fontsize=13)
plt.text(-omega_c - 0.5, np.pi*A + 0.1, r'$\pi A$', fontsize=13)
plt.text(omega_c - 0.4, -0.08, r'$\omega_c$', fontsize=13)
plt.text(-omega_c - 0.7, -0.08, r'$-\omega_c$', fontsize=13)
plt.text(0.2, 0.55, r'$\frac{1}{2}$', fontsize=13)
plt.text(9, 0.6, r'$X(j\omega)$', fontsize=14)
plt.xlabel(r'$\omega$', fontsize=14)

# محورهای پررنگ
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=2)

# تنظیمات نهایی
plt.ylim(-0.2, np.pi*A + 1)
plt.yticks([])
plt.grid(False)
plt.title(r'Spectrum $X(j\omega)$ with Triangular Pulses and Dirac Deltas (Arrows)')

plt.show()

# %% [markdown]
# شکل های 8.14
# مقایسه طیف های سیستمهای مدولاسیون دامنه سینوسی همزمان و ناهمزمان

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(8, 8))

# توابع ورودی
inputs = ['x_a(t)', 'x_b(t)', 'x_c(t)', '...']
outputs = ['y_a(t)', 'y_b(t)', 'y_c(t)', '']
omegas = [r'$\cos(\omega_a t)$', r'$\cos(\omega_b t)$', r'$\cos(\omega_c t)$', '']

# موقعیت‌ها
x_start = 0.5
x_middle = 2.5
x_end = 4
y_positions = [6, 4, 2, 0.5]

# رسم خطوط ورودی، ضرب‌کننده و برچسب‌ها
for i, y in enumerate(y_positions):
    # خط ورودی
    ax.arrow(x_start - 0.3, y, 0.3, 0, head_width=0.15, head_length=0.1, fc='GRAY', ec='GRAY')
    ax.text(x_start - 0.5, y, inputs[i], fontsize=12, va='center')

    # بلوک ضرب (دایره)
    circle = patches.Circle((x_start, y), 0.2, fill=False)
    ax.add_patch(circle)
    ax.text(x_start, y, '×', ha='center', va='center', fontsize=14)

    # ω_cos
    ax.arrow(x_start, y + 1, 0, -0.8, head_width=0.1, head_length=0.15, fc='GRAY', ec='GRAY')
    ax.text(x_start + 0.1, y + 0.6, omegas[i], fontsize=12)

    # خروجی از ضرب‌کننده
    ax.arrow(x_start + 0.2, y, x_middle - (x_start + 0.2), 0, head_width=0.15, head_length=0.15, fc='BLACK', ec='BLACK')
    if outputs[i]:
        ax.text((x_start + x_middle) / 2, y + 0.2, outputs[i], fontsize=12)

    # اتصال به جمع‌کننده
    ax.plot([x_middle, x_end - 0.2], [y, y], color='BLACK')
    ax.arrow(x_end - 0.2, y, 0.2, (4 - y), head_width=0.15, head_length=0.15, fc='black', ec='black')

# جمع‌کننده
circle_sum = patches.Circle((x_end, 4), 0.25, fill=False)
ax.add_patch(circle_sum)
ax.text(x_end, 4, '+', ha='center', va='center', fontsize=14)

# خروجی w(t)
ax.arrow(x_end + 0.25, 4, 1, 0, head_width=0.15, head_length=0.2, fc='GRAY', ec='GRAY')
ax.text(x_end + 1.3, 4, 'w(t)', fontsize=12)

# تنظیمات کلی
ax.set_xlim(-0.5, 6)
ax.set_ylim(0, 7)
ax.axis('off')
plt.title('Frequency multiplexing diagram with sinusoidal modulation (AM)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# مالتی پلکس فرکانسی با استفاده از مدولاسیون دامنه سینوسی
# شکل 8.15

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# ایجاد یک شکل و محورها
fig, ax = plt.subplots(figsize=(8, 3))
ax.axis('off')  # خاموش کردن محور‌ها

# رسم فلش ورودی
ax.arrow(0.1, 0.5, 0.2, 0, head_width=0.05, head_length=0.03, fc='k', ec='k')
ax.text(0.05, 0.52, 'Y(t)', fontsize=12)

# رسم بلوک سیستم
block = patches.FancyBboxPatch((0.3, 0.35), 0.4, 0.3,
                               boxstyle="round,pad=0.02", linewidth=1.5, edgecolor='black', facecolor='none')
ax.add_patch(block)
ax.text(0.5, 0.5, 'H(jω)', ha='center', va='center', fontsize=13)

# رسم فلش خروجی
ax.arrow(0.7, 0.5, 0.2, 0, head_width=0.05, head_length=0.03, fc='k', ec='k')
ax.text(0.91, 0.52, 'Yᵤ(t)', fontsize=12)

# نمایش شکل
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# تعریف بازه فرکانسی
omega = np.linspace(-10, 10, 1000)
omega_c = 3

# تعریف تابع پاسخ فرکانسی H(jω)
H = np.ones_like(omega)
H[np.logical_and(omega > -omega_c, omega < omega_c)] = 0

# رسم نمودار
plt.figure(figsize=(8, 3))
plt.plot(omega, H, color='BLUE', linewidth=2)

# خطوط عمودی در ±ω_c
plt.vlines([-omega_c, omega_c], 0, 1, colors='black', linestyles='solid')

# برچسب‌ها و خطوط راهنما
plt.xticks([-omega_c, 0, omega_c], [r'$-\omega_c$', r'$0$', r'$\omega_c$'])
plt.yticks([0, 1], ['0', '1'])
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.xlabel(r'$\omega$')
plt.ylabel(r'$H(j\omega)$')
plt.title('Frequency response of a band-pass filter')
plt.grid(False)
plt.ylim(-0.2, 1.2)
plt.xlim(-10, 10)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# پارامترها
omega_c = 4
width = 2
height = 0.5
omega = np.linspace(-10, 10, 1000)
X = np.zeros_like(omega)

# تابع پالس مثلثی
def triangle_pulse(center, width, height):
    slope = height / width
    return np.maximum(0, height - slope * np.abs(omega - center))

# جمع دو پالس مثلثی حول ±ω_c
X += triangle_pulse(omega_c, width, height)
X += triangle_pulse(-omega_c, width, height)

# ترسیم
plt.figure(figsize=(10, 4))
plt.plot(omega, X, color='YELLOW', linewidth=2)

# محورهای پررنگ
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=2)

# برچسب‌ها
plt.text(0.2, 0.55, r'$\frac{1}{2}$', fontsize=13)
plt.text(omega_c - 0.5, -0.08, r'$\omega_c$', fontsize=13)
plt.text(-omega_c - 0.7, -0.08, r'$-\omega_c$', fontsize=13)
plt.text(9, 0.6, r'$X(j\omega)$', fontsize=14)
plt.xlabel(r'$\omega$', fontsize=14)

# تنظیمات گرافیکی
plt.ylim(-0.2, 0.7)
plt.yticks([])
plt.grid(False)
plt.title('Double Triangular Spectrum $X(j\\omega)$')

plt.show()

# %% [markdown]
# سیستمی برای حفظ کنار باند های بالا به کمک فیلتر میان گذر
# شکل 8.16

# %%
import numpy as np
import matplotlib.pyplot as plt

# دامنه فرکانس
omega = np.linspace(-10, 10, 1000)
H = np.ones_like(omega)  # پاسخ فرکانسی = 1 برای همه ω

# ترسیم
plt.figure(figsize=(6, 3))
plt.plot(omega, H, color='red', linewidth=3)

# محورهای پررنگ
plt.axhline(0, color='black', linewidth=2)  # محور افقی
plt.axvline(0, color='black', linewidth=2)  # محور عمودی

# برچسب‌ها
plt.text(0.2, 1.05, '1', fontsize=12)
plt.text(9, 1.1, r'$H(j\omega)$', fontsize=14)
plt.xlabel(r'$\omega$', fontsize=12)
plt.ylim(0, 1.5)
plt.grid(False)
plt.yticks([])
plt.title('Magnitude Response of H(jω)')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# تعریف دامنه امگا
omega = np.linspace(-10, 10, 1000)

# تعریف فاز: برای omega کمتر از صفر pi/2 و برای omega بزرگتر از صفر -pi/2.
phase = np.where(omega < 0, np.pi/2, -np.pi/2)

# ایجاد نمودار
plt.figure(figsize=(8, 4))
plt.plot(omega, phase, color='blue', linewidth=3)

# پررنگ کردن محورهای مختصات
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=2)

# اضافه کردن برچسب‌ها و عنوان
plt.xlabel(r'$\omega$', fontsize=14)
plt.ylabel('Phase (radians)', fontsize=14)
plt.title('Phase Response', fontsize=16)

# تنظیم بازه محور عمودی برای نمایش بهتر مقادیر π/2 و -π/2
plt.ylim(-2, 2)

# اضافه کردن خطوط راهنما برای مشخص بودن π/2 و -π/2
plt.axhline(np.pi/2, color='gray', linestyle='--', linewidth=1)
plt.axhline(-np.pi/2, color='gray', linestyle='--', linewidth=1)

# نمایش نمودار
plt.show()

# %% [markdown]
# شکل 8.17
# سیستم مدولاسیون دامنه تک کنار باندی با استفاده از مدار تغییر فاز

# %%
import numpy as np
import matplotlib.pyplot as plt

# تعریف ω از -10 تا 10
omega = np.linspace(-10, 10, 1000)

# پالس صاف شده با استفاده از تابع هانیگ روی بازه [-2, 2]
X = np.zeros_like(omega)
mask = np.abs(omega) <= 2
X[mask] = 0.5 * (1 + np.cos(np.pi * omega[mask] / 2))

# ترسیم نمودار
plt.figure(figsize=(8, 4))
plt.plot(omega, X, color='grAY', linewidth=2)

# محورهای پررنگ
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=2)

# برچسب‌ها
plt.text(0.1, 1.05, '1', fontsize=12)
plt.text(0.5, 1.2, r'$X(j\omega)$', fontsize=14)
plt.xlabel(r'$\omega$', fontsize=14)

# تنظیمات گرافیکی
plt.ylim(-0.2, 1.5)
plt.grid(False)
plt.title('Double Triangular Spectrum $X(j\\omega)$', fontsize=16)

plt.show()

# %% [markdown]
# شکل 8.22

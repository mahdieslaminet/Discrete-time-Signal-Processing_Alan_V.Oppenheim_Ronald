# %% [markdown]
# (1,1) اعداد مختالط زير را به شكل قائم (x+ jy ) بنويسِي
#
# $$
# : \sqrt{2} e^{-j / 4} \cdot \sqrt{2} e^{-j 9 \pi / 4} \cdot \sqrt{2} e^{j 9 \pi / 4} \cdot \sqrt{2} e^{j \pi / 4} \cdot e^{j 5 \pi / 2} \cdot e^{-j \pi / 2} \cdot e^{j \pi / 2} \cdot \frac{1}{2} e^{-j \pi} \cdot \frac{1}{2} e^{j \pi}
# $$
#
#
# با تبايل كردن مختصات قطبى به كارتزين داريم:
#
# $$
# \begin{aligned}
# & 1 / 2 e^{j \pi}=1 / 2 \cos \pi=-1 / 2 \\
# & e^{\pi / 2 j}=\cos (\pi / 2)+j \sin (\pi / 2)=j \\
# & e^{5 j \pi / 2}=j \\
# & \sqrt{2} e^{j \frac{\pi}{j}}=\sqrt{2} e^{3 \pi / 6}=1+j \\
# & \sqrt{2} e^{-3 \pi / 4}=1-j
# \end{aligned}
# $$
#
#
# $$
# \begin{aligned}
# & 1 / 2 e^{-j n}=1 / 2 \cos (-n)=-1 / 2 \\
# & e^{-j \pi / 2}=\cos (\pi / 2)-j \sin \pi / 2=-j \\
# & \sqrt{2} e^{j \pi / 4}=\sqrt{2}(\cos j n / 4)+j \sin (n / 4)=1+j \\
# & \sqrt{2} e^{\frac{-3 \pi j}{4}}=\sqrt{2} e^{-\frac{j \pi}{4}}=1-j
# \end{aligned}
# $$

# %% [markdown]
# $$
# \left(-\pi<\theta \leq \pi \text { با ، } r e^{j \theta}\right) \text { (1) }
# $$

# %% [markdown]
# اعداد مختلط زير را به شكل قطبي بنويسيد $$
# \left(-\pi<\theta \leq \pi \text { با ، } r e^{j \theta}\right) \text { (1) }
# $$

# %% [markdown]
# $$
# \begin{array}{r}
# (1+j) /(1-j) \cdot j(1-j) \cdot(1-j)^2 \cdot 1+j \cdot \frac{1}{2}-j \frac{\sqrt{3}}{2} \cdot-3 j \cdot-8 \cdot Y \\
# (\sqrt{2}+j \sqrt{2}) /(1+j \sqrt{3})
# \end{array}
# $$
# حل
# با تبديل كردن مختصات كارتزين به قطبي داريم :
#
# $$
# \begin{aligned}
# & 5=5 e^{j o}, \\
# & -2=2 e^{j \pi}, \\
# & -3=3 e^{-j \pi / 2} \\
# & 1 / 2=j \sqrt{3 / 2}=e^{-j \pi / 8}, \\
# & \frac{1+j}{1-j}=e^{j \pi / 2}, \\
# & \frac{\sqrt{2}+j \sqrt{2}}{1+\sqrt{3} j}=e^{-j \pi / B}
# \end{aligned}
# $$
#
#
# $$
# \begin{array}{r}
# x_1(t)=e^{-2 t} u(t) \\
# x_2(t)=e^{\prime}(2 t+\pi / 4) \\
# x_3(t)=\cos t \\
# x_1[n]=\left(\frac{1}{2}\right)^n u[n] \\
# x_2[n]=e^{\prime}(n \pi / 2+\pi / 8) \\
# x_3[n]=\cos \left(\frac{\pi}{4} n\right)
# \end{array}
# $$

# %% [markdown]
# (1,3 P∞
# E∞ و
#  را براي هر يك از سيگنالهاي زير پيدا كنيد .
# \begin{array}{r}
# x_1(t)=e^{-2 t} u(t) \\
# x_2(t)=e^{\prime}(2 t+\pi / 4) \\
# x_3(t)=\cos t \\
# x_1[n]=\left(\frac{1}{2}\right)^n u[n] \\
# x_2[n]=e^{\prime}(n \pi / 2+\pi / 8) \\
# x_3[n]=\cos \left(\frac{\pi}{4} n\right)
# \end{array}

# %% [markdown]
# $$
# \begin{aligned}
# &\text { : } \downarrow\\
# &\text { ، } E_m<\infty \text { الفer) }\\
# &\begin{aligned}
# & E_m=\int_0^{\infty} e^{-\infty} d t=\frac{1}{4} \Rightarrow P_m=0 \\
# & \text { بنابراين } x_2(t)=e^{j(2+2 / 4},\left|x_2(t)\right|=1(ب \\
# & E_{\infty}=\int_{-\infty}^{\infty}\left|x_2(t)\right|^2 d t=\int_{-\infty}^{+\infty} d t=\infty \text {. } \\
# & p_{\infty}=\operatorname{Limit}_{N \rightarrow m} \frac{1}{2 T} \int_{-T}^T\left|x_2(t)\right| d t=\operatorname{Limit}_{N \rightarrow \infty} \frac{1}{2 T} \int_{-T}^T d t=1 \\
# & \text { بنابراين } x_3(t)=\cos t \\
# & E_x=\int_{-\infty}^{\infty}\left|x_3(t)\right|^{+} d t=\int_{-\infty}^{+\infty} \cos ^2(t) d t=\infty \\
# & P_{-}=\operatorname{Lim}_{N \rightarrow \infty} \frac{1}{2 T} \int_{-T}^T \cos ^2 t d t-\operatorname{Lim}_{N \rightarrow \infty} \frac{1}{2 T} \int_{-T}^T \frac{1+\cos (t)}{2} d t=\frac{1}{2} \\
# & \sim \mid x_1\left[\left.n\right|^2=(1 / 4)^r u[n] \quad, \quad x_1[n]=(1 / 2)^r u[n] \rho_{y-1}(2\right. \\
# & E_m<\infty \quad U_{y-} \\
# & E_{\infty}=\sum_{n=-\infty}^{+\infty}\left|x_1[n]\right|^2=\sum_{\infty}^{+\infty}(1 / 4)^n=4 \quad . \quad p_{\infty}=0 \\
# & \text { بنابراين } \mid x_2[n]^2=1, x_2[n]=e^{-j(2 x / 3+6 / 6)} \\
# & \underset{-}{\infty}\left|x_2[n]\right|^2=\infty \quad, \quad p_{-}=\underset{N \rightarrow \infty}{\operatorname{Lim}} \frac{1}{2 N+1} \sum_{-N}^N\left|x_2[n]\right|^2=\underset{N \rightarrow \infty}{\operatorname{Lim}} \frac{1}{2 N+1} \sum_{-N}^N 1=1 \\
# & \text { و } \\
# & E_m=\underset{-\infty}{\stackrel{+}{n}} \mid x_3[n]^2=\underset{\sim}{+\infty} \cos ^2(n / 4 n)=\infty \\
# & P_{-}=\operatorname{Lim}_{N \rightarrow \infty} \frac{1}{2 N+1} \sum_{-N}^N \cos (\pi / 4 n)=\operatorname{Lim}_{N \rightarrow \infty} \frac{1}{N+1}\left(\frac{1+\cos (\pi / 2 n)}{2}\right)=1 / 2
# \end{aligned}
# \end{aligned}
# $$

# %% [markdown]
# ١,٤) فرض کنید x[n سیگنالی باشد که در 2n >و 4<n صفر است. هر یک از سيگنالهاى زير
# در چه بازه هايى صفر هستند؟
# الف) 3-x[n]
# ب) 4+x[n]
#
# د) 2+x[-n]
# هـ) 2-x[-n]
# حل:
# الف) سیگنال [x[n ٣ واحد به سمت راست شیفت یافته است، سیگنال شيفت يافته برای 1>n و
# 7<n برابر صفر است.
#
# ب) سيكنال [x[n ٤ واحد به سمت چب شيفت يافته است، سيكنال شيفت يافته براى 6 -> n و
# n>o برابر صفر است.
#
# ج) سيكنال x[n] معكوس شده است. پس سيكنال معكوس شده بر 4 -> n و2<n صفر است.
# د) سیگنال x[n] معکوس شده و ٢ واحد به سمت راست شیفت یافته است، سیگنال جدید براى
# 2 -> n و 4<n صفر است.
# هـ) سيكنال x[n] معكوس شده وآن هم ٢ واحد به سمت شيفت يافته است.

# %% [markdown]
#  فرض کنید  سیگنالی باشد که در t<3 صفر شده است. سیگنالهای زیر به ازای چه
# مقاديرى از t صفر خواهند بود؟
# الف) x(1-t)
# ب) (1-2)x(1-1)+x
# ج) (1-2)x(1-1)x
# د) (x(3r
# هـ) (1/3)x
# حل:

# %% [markdown]
# درمورد متناوب بودن یا نبودن سیگنال های زیر تحقیق کنید
# $$
# \begin{array}{r}
# x(t)=2 e^{j(t+\pi / 4)} u(t) \ \\
# x_2[n]=u[n]-u[-n] \\
# x_3[n]=\sum_{k=-\infty}^{\infty}\{\delta[n-4 k]-\delta[n-1--4 k]\}
# \end{array}
# $$
# حل:
# الف) (X(t متناوب نیست زیرا برای ٥<t صفر شده است.
# ب)به ازاى همه مقادير x[n] =1 m است وتابع متناوب با دوره تناوب ١ مى باشد.
# ج) [x3[n در شكل (١,٦ح) رسم شده است.

# %% [markdown]
# ![Screenshot 2025-06-06 170946.png](data:image/png;base64,...)

# %% [markdown]
# براي سيگنالهاي زير مقا دير متغير مستقل را كه به ازاي آنها بخـش زوج سـيگنال صفرسـت پيـدا
# كنيد
# $$
# \begin{gathered}
# x_1[n]=u[n]-u[n-4] \\
# x_2(t)=\sin \left(\frac{1}{2} t\right) \\
# x_3[n]=\left(\frac{1}{2}\right)^n u[n-3] \\
# x_4(t)=e^{-5 t} u(x+2)
# \end{gathered}
# $$
#
#
#
# $$
# \mathcal{Q}\left\{x_1[n]\right\}=\frac{1}{2}\left\{x_1[n]+x_1[-n]\right\}=\frac{1}{2}\{u[n]-u[n-4]+u[-n]-u[-n-4]\}
# $$
#
#
# براي n>3  برابر صفر است
# $$
# v\left\{x_3(t)\right\}^{-} 1 / 2\left\{x_1[n]+x_1[-n]\right\}=1 / 2(1 / 2)^n u[n-3]-(1 / 2)^{-n} u[-n-3]
# $$
#
# b)
# ه ازاي تمام مقادير t صفر است
# $$
# \varepsilon v\left\{x_4(t)\right\}=1 / 2\left(x_4(t)\right)+\left(x_4(t)+x_4(-t)\right)=1 / 2\left\{e^{-5 t} u(t+2)-e^{+5 t} u(-t+2)\right\}
# $$
#
#
# بنابراين
# براي ∞ → t برابر صفر است

# %% [markdown]
# قسمت حقيقي سيگنالهاي زير را بـه صـورت
# $$
# A e^{-a t} \cos (\omega t+\phi)
# $$
# at φ و ω ، a ،A $$،بنويـسيد
# hunhn prdrd hkn
# $$
# \begin{array}{r}
# x_1(t)=-2 \text { } \\
# x_2(t)=\sqrt{2} e^{j \pi / 4} \cos (3 t+2 \pi) \\
# x_3(t)=e^{-t} \sin (3 t+\pi)
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# &\operatorname{Re} a d\left\{x_1(t)\right\} y=-2=2 e^{0 t} \cos (o t+\pi)\\
# &\operatorname{Re}\left\{x_2(t)\right\}=\sqrt{2} \cos (\pi / 4) \cos (3 t+2 n)=\cos 3 t=e^{u t} \cos (3 t+o)\\
# &\operatorname{Re}\left\{x_3(t)\right\}=e^{-t} \sin (3 t+n)=e^{-t} \cos (3 t+\pi / 2)
# \end{aligned}
# $$

# %% [markdown]
# )1,9 در مورد متناوب بودن يا نبودن سيگنال هاي زيـر تحقيـق كنيـد . بـراي سـيگنالهاي متنـاوب دوره
# تناوب اصلي را بيابيد

# %% [markdown]
# $$
# \begin{gathered}
# x_1(t)=j e^{j 10 t} \\
# x_2(t)=e^{(-1+j) t} \\
# x_3[n]=e^{j v \pi n} \\
# x_4[n]=3 e^{j 3 \pi(n+1 / 2) / 5} \\
# x_5[n]=3 e^{j 3(n+1 / 2) / 5}
# \end{gathered}
# $$

# %% [markdown]
# الف ) دوره تناوب r/5
# يك نمايي مختط متناوب است

# %% [markdown]
# یک نمايي مختط ضرب شده به يك تأخير نمايي است، ازينرو نامتناوب

# %% [markdown]
# ج)يك سيگنال نمايي مختلط با دوره تناوب اصلي 2

# %% [markdown]
# د)سيگنال متناوب با دوره تناوب10

# %% [markdown]
# ه)نامتناوب

# %% [markdown]
# 10)دوره تناوب اصلی$$
# x(t)=2 \cos (10 t+1)-\sin (4 t-1)
# $$

# %% [markdown]
# پریود جمله اول پی پنجم و جمله دوم چی دوم است پس پی

# %% [markdown]
# 12)
# دوره تناوب اصلی
# $$
# \text { . } x[n]=1+e^{j 4 \pi d t / 7}-e^{j 2 \pi t / 5}
# $$
# حل
# دوره تناوب جمله اول برحسب RHS 1 است .
#  RHS 7

# %% [markdown]
# هرگاه ،  دوره تناوب جمله ي سوم برحسب RHS برابر 5

# %% [markdown]
# ک.م.م:35

# %% [markdown]
# 1,12) سيگنال گسسته در زمان زير را در نظر بگيريد .

# %% [markdown]
# $$
# x[n]=1-\sum_{k=3}^{\infty} \delta[n-1-k]
# $$

# %% [markdown]
# n اعداد M و
#  را طوري تعيين كنيد كه بتوانx[n] را به صورت زير بيان كرد
# $x[n]=u\left[M n-n_0\right]$m

# %% [markdown]
# شکل سیگنال در کتاب نشان داده شده پس از معکوس کردن و انقال 3
# واحد به راست بدست مي آيد. بنابراين
#  M = − ,1 n = −3

# %% [markdown]
# 1,13) سيگنال پيوسته در زمان زير را در نظر بگيريد .

# %% [markdown]
# $$
# x(t)=\delta(t+2)-\delta(t-2)
# $$
#
# . سيگنال زير را بدست آوريد.
#
# $$
# y(t)=\int_{-\infty}^t x(\tau) d \tau
# $$
#
# پ
#
# $$
# \begin{aligned}
# y(t)=\int_{-\infty}^t x(\tau) d c & =\int_{-\infty}^t \delta(\tau+2)-\delta(\tau-2) d t \\
# & =\left\{\begin{array}{cc}
# 0 & t<-2 \\
# 1 & -2 \leq t \leq 2 \\
# 0 & t>2
# \end{array}\right.
# \end{aligned}
# $$
#
# $E \infty=\int_{-2}^2 d t=4$ بنابراين
# (1,1 £) سيگنال  متناوب

# %% [markdown]
# 14)سیگنال متناوب زیر ر به دست آورید

# %% [markdown]
# $$
# x(t)= \begin{cases}1, & \circ \leq t \leq 1 \\ -2, & 1<t<2\end{cases}
# $$

# %% [markdown]
# داراي تناوب 2 = T است. مشتق اين سيگنال «به قطار ضربه» زير مربوط مي شود
# $$
# g(t)=\sum_{k=-\infty}^{+\infty} \delta(t-2 k)
# $$
#
#
# مى توان نسّان داد كه:
#
# $$
# \frac{d x(t)}{d t}=A_1 g\left(t-t_1\right)+A_2 g\left(t-t_2\right)
# $$
#
#
# هقادير $A_1$ ، $A_1$ ، و $A_2$ را محاسبه كنيا.

# %% [markdown]
# ![122.png](data:image/png;base64,...)

# %% [markdown]
# (سيستم S با ورودي [n[x را در نظر بگيريد . اين سيستم از اتصال سري سيـستم
# s1 , s2
# به دست آمده اند
#
# $$
# \begin{aligned}
# & S_2: y_1[n]=2 x_1[n]+4 x_1[n-1] \\
# & S_2: y_2[n]=x_2[n-2]+\frac{1}{2} x_2[\pi-3]
# \end{aligned}
# $$
#
# s1 , s2
# ورودی هستند

# %% [markdown]
# لف) رابطه ورودي ـ خروجي سيستم S را بيابيد .
# 2S رابطه ورودي ـ خروجي S تغيير مي كند يا نه؟
# 1S و
# ب) آيا با تعويض ترتيب سيستمهاي
# حل

# %% [markdown]
# الف)
#
# $$
# \begin{aligned}
# y_2[n] & =x_2[n-2]+1 / 2 x_2[n-3] \\
# & =y_1[n-2]+1 / 2 y_1[n-3] \\
# & =2 x_1[n-2]+4 x_1[n-3]+1 / 2\left(2 x_1[n-3]+4 x_1[n-4]\right) \\
# & =2 x_1[n-2]+5 x_1[n-3]+2 n_1[n-4]
# \end{aligned}
# $$
#
#
#
# $$
# y[n]=2[n-2]+5 x[n-3]+2 x[n-4]
# $$
#
#
# ب)
# $$
# \begin{aligned}
# y_1[n] & =2 x_1[n]+4 x_1[n-1] \\
# & =2 y_2[n]+4 y_2[n-1] \\
# & =2\left(x_2[n-2]+1 / 2 x_2[n-3]\right)+4\left(x_2[n-3]+1 / 2 x_2[n-4]\right) \\
# & =2 x_2[n-2]+5 x_2[n-3]+2 x_2[n-2]
# \end{aligned}
# $$
#
#
#
# $$
# y[n]=2 x[n-2]+S x[n-3]+2 n[n-4]
# $$

# %% [markdown]
# 1,18) يك سيستم پيوسته در رمان با ورودي وخروجي ، با رابطه زير در نظر بگيريد .

# %% [markdown]
# $$
# y[n]=\sum_{k=n-n_{,}}^{n+n} x[k]
# $$
#
#
# الف) آيا اين سيستم خطى است؟
# ب) آيا اين سيستم تغيرنإيذير با زمان است؟ است. C, ا بر حسب B و بياييا.
# v
#
# الف) دو ورودى دلخواه را درنظر بگیرید
#
# $$
# \begin{aligned}
# & x_1[n] \rightarrow y_1[n]=\sum_{k=n-n_*}^{n+n_1} x_1[k] \\
# & x_2[n] \rightarrow y_2[n]=\sum_{n-n_1}^{n+n_2} x_2[k]
# \end{aligned}
# $$
#
#
# $$
# x_3[n]=\alpha x_1[n]+b x_2[n]
# $$
#  خروجى متناظر $y_3[n]$ برابر است با

# %% [markdown]
# $$
# \begin{aligned}
# y_2[n] & =\sum_{n-n_s}^{n+n_s} x_3[k] \\
# & =\sum_{n-n_s}^{n+n_s}\left(\alpha n_1[k]+b x_2[k]\right)=\alpha \sum_{n-n_s}^{n+n_s} x_1[k]+b \sum_{n-n_s}^{n+n_s} x_2[k] \\
# & =\alpha y_1[n]+b y=[n]
# \end{aligned}
# $$
#
#
# بنابر اين سِستم خطى است.
#
# $$
# x_2[n]=x_1\left[n-n_1\right]
# $$
#
#
# خروجى متناظر با اين ورودى برابر است با:
#
# $$
# y_2[n]=\sum_{n-n_s}^{n+n_s} x_2[k]=\sum_{n-n_s}^{n+n_s} x_1\left[k-n_1\right]=\sum_{n-n_1-n_s}^{n-n_1+n_s} n_1[k]
# $$
#
#
# بنابراين توجه كنید كه
#
# $$
# y_1\left[n-n_1\right]=\sum_{n-n_1-n_2}^{n-n_1-n_2} x_1[k]
# $$
#
#
# بنابر اين
#
# $$
# y_2[n]=y_1\left[n-n_1\right]
# $$
#
#
# اين نشان می دهد که سیستم تغير ناپذیر با زمان است.
#
# $$
# y[n] \leq\left(2 n_{\circ}+1\right) \beta
# $$
#
# $C \leq\left(2 n_0+1\right) \beta$ بنابراين

# %% [markdown]
# 9 ) به ازاي روابط ورودي ـ خروجي داده شده تعيين كنيد سيستم خطي است، تغييرناپذير با زمـان
# است، يا هر دو

# %% [markdown]
# $$
# \begin{array}{r}
# y(t)=t^2 x(t-1) \\
# y[n]=x[n+1]-x[n-1]
# \end{array}
# $$
# $$
# \begin{array}{r}
# y[n]=x^2[n-2] \\
# y[n]=v x\{x[n]\}
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# & x_1(t) \rightarrow y_1(t)=t^2 x_1(t-1) \\
# & x_2(t) \rightarrow y_2(t)=t^2 x_2(t-1)
# \end{aligned}
# $$
#  $x_3(t)=t_2 x_3(t-1)$
#
# خروجى متناظر (t) $y_3(t)$
#
# $$
# =t^2\left(\alpha n_1(t-1)+b x_2(t-1)\right)=\alpha y_1(t) t b y_2(t)
# $$
#
#
# بنابراين سيستم خطى است.
# ورودى دلخواه (Ii
#
# $$
# y_1(t)=t^2 x_1(t-1)
# $$
#
#
# خروجى متناظر باشله، ورودى ( $x_2(t)$ از شَيفت يافتن $x_1(t)$ در زمان بادست خواهد آماد:
#
# $$
# x_2(t)=x_1(t-t)
# $$
#
#
# خروجى متناظر اين سيُنال برابر است با:
#
# $$
# y_2(t)=t^2 x_2(t-1)=t^2 x_1\left(t-1-t_{\circ}\right)
# $$
#
# همچينين بخاطر داشته باشيد كه
#
# $$
# y_1\left(t-t_{\circ}\right)=\left(t-t_{\circ}\right)^2 x_1\left(t-1-t_{\circ}\right) \neq y_2(t)
# $$
#
#
# بنابراين سيستم تغيير پإِير با زمان است.
# ب) (i) دو روى دلخواه 1
#
# $$
# x_1[n] \rightarrow y_1[n]=x_1^2[n-2]
# $$
#
#
# $$
# x_2[n] \rightarrow y_2[n]=x_2^2[n-2]
# $$
#
#
# را تركيب خطى $x_3[n]$
#
# $$
# \begin{aligned}
# & x_1[n] \rightarrow y_1[n]=x_1^2[n-2] \\
# & x_2[n] \rightarrow y_2[n]=x_2^2[n-2]
# \end{aligned}
# $$
#
#
# $$
# x_3[n]=\alpha n_1[n]+b x_2[n]
# $$

# %% [markdown]
# خروجى هتناظر برابر است با:
#
# $$
# \begin{aligned}
# y_3[n]= & x_3^2[n-2] \\
# = & \left(\alpha x_1[n-2]+b x_2[n-2]\right)^2 \\
# = & a^2 x_1^2[n-2]+b^2 \cdot x_2^2[n-2]+2 a b x_1[n-2] x_2[n-2] \\
# & \neq a y_1[n]+b y_2[n]
# \end{aligned}
# $$
#
#
#  $y_1[n]=x_1^2[n-2]$
# خروجى متناظر باشد. ورودى دوم $x_2$ در زمان بدست مى آيد: $x_2[n]=x_1\left[n-n_{\circ}\right]$
#
# خروجى هتناظر برابر است با:
#
# $$
# y_2[n]=x_2^2[n-2]=n_1^2\left[n-2-n_o\right]
# $$
#
#
# توجه داشته باشيد كد:
#
# $$
# y_1\left[n-n_{\circ}\right]=n_1^2\left[n-2-n_{\circ}\right]
# $$
#
#
# بنابراين:
#
# $$
# y_2[n]=y_1\left[n-n_{\mathrm{o}}\right]
# $$
#
#
# كه نشان مى دهد سيستم تغييرنإِندِير با زمان است.
#
# $$
# \begin{aligned}
# & x_1[n] \rightarrow y_1[n]=x_1[n+1]-x_1[n-1] \\
# & x_2[n] \rightarrow y_2[n]=x_2[n+1]-x_2[n-1]
# \end{aligned}
# $$
#
#
# $$
# x_3[n]=\alpha x_1[n]+b \quad x_2[n]
# $$
#  متناظر $y_3$ برابر است با:

# %% [markdown]
# $$
# \begin{aligned}
# y_3[n]= & x_3[n+1]-x_3[n-1] \\
# = & a \cdot x_1[n+1]+b x_1[n+1]-a x_1[n-1]-b x_2[n-1] \\
# = & a\left(x_1[n+1]+x_1[n-1]\right)+b\left(x_2[n+1]-x_2[n-1]\right) \\
# & a y_1[n]+b y=y[n]
# \end{aligned}
# $$
#
#
# بنابراين سيستم خطى است زمانى بدست مى آيد.
# اكر
#
# $$
# y_2[n]=x_2[n+1]-x_2[n-1]=x_1\left[n+1=n_{\circ}\right]-n_1\left[n-1-n_{\circ}\right]
# $$
#
#
# $$
# y\left[n-n_{\circ}\right]=x_1\left[n+1-n_{\circ}\right]-n_1\left[n-1-n_{\circ}\right]
# $$
#
#
# بنابر اين
#
# $$
# y_2[2]=y_1\left[n-n_{\circ}\right]
# $$
#
#
# و بيان هى كند كه سيستم تغيير ناپذير با زمان است.
# (i
#
# $$
# \begin{aligned}
# & x_1(t) \rightarrow y_1(t)=\operatorname{od}\left\{x_1(t)\right\} \\
# & x_2(t) \rightarrow y_2(t)=\operatorname{od}\left\{x_1(t)\right\}
# \end{aligned}
# $$
#
#
# $$
# x_3(t)=\alpha x_1(t)+b x_2(t)
# $$
#
#
# صورت خروجى هتناظر با اين ورودى برابر است با:
#
# $$
# \begin{aligned}
# y_3(t) & =\operatorname{od}\left\{x_3(t)\right\}=\operatorname{od}\left\{\alpha x_1(t)+b x_2(t)\right\} \\
# & =a \operatorname{od}\left\{x_1(t)\right\}+b \operatorname{od}\left\{x_2(t)\right\}=a y_1(t)+b y_2(t)
# \end{aligned}
# $$
#
#
# بنابر اين سيستم خطى است.

# %% [markdown]
# $$
# x_1(t)=\cos (2 t) \rightarrow y_1(t)=\cos (3 t)
# $$
#
# ب) مى دانيم:
#
# $$
# x_2(t)=\cos (2(t-1 / 2))=\frac{e^{-j} e^{j 2 t}+e^j e^{j 2 t}}{2}
# $$
#
#
# با استغاده از خاصيت خطى بودن داريم:
#
# $$
# x_1(t)=1 / 2\left(e^{-j} e^{j 2 t}+e^j e^{-2 j t}\right) \rightarrow y_1(t)=1 / 2\left(e^{-j} e^{3 j t}+e^j e^{-j 3 t}\right)=\cos (3 t-1)
# $$
#
#
# بنابر اين
#
# $$
# x_1(t)=\cos (2(t-1 / 2)) \rightarrow y(t)=\cos (3 t-1)
# $$
#
#
# هقداردهى كنيل.

# %% [markdown]
# 1) شكل م 1- 21 سـيگنال پيوسـته در زمـان  را نـشان مـي دهـد . سـيگنالهاي زيـر را رسـم و
# مقداردهي كنيد .

# %% [markdown]
# الف) (1) $x(t-1$
# $x(2-t)$ (ب
# $x(2 t+1)$ (そ
# $\left(x 4-\frac{t}{2}\right)$ (2
# $[x(t)+x(-t) u(t)] \leftrightarrow$
#
# $$
# \left(x(t) \delta\left(t+\frac{3}{2}\right)-\delta\left(t-\frac{3}{2}\right)\right)
# $$

# %% [markdown]
# ![217.png](data:image/png;base64,...)

# %% [markdown]
# ![28.png](data:image/png;base64,...)

# %% [markdown]
# ![221.png](data:image/png;base64,...)![22.png](data:image/png;base64,...)

# %% [markdown]
# 3) بخشهاي زوج و فرد سيگنالهاي شكل م 1- 23 را تعيين، و آنها را رسم و به دقـت مقدارگـذاري
# كنيد
# ![23.png](data:image/png;base64,...)

# %% [markdown]
# حل:

# %% [markdown]
# ![24.png](data:image/png;base64,...)

# %% [markdown]
# 4) بخشهاي زوج و فرد سيگنالهاي شكل م 1- 24 را تعيين، و آنها را رسم و به دقـت مقدارگـذاري
# كنيد

# %% [markdown]
# ![241.png](data:image/png;base64,...)

# %% [markdown]
# $x(t)=3 \cos \left(4 t+\frac{\pi}{3}\right)$ الف
#
# $$
# \begin{aligned}
# x(t)=\left[\cos \left(2 t-\frac{\pi}{3}\right)\right]^2 & \left(\tau x(t)=e^{j(\pi t-1)}\right. \\ب)
# x(t) & =\xi\{\cos (4 \pi t) u(t)\} \\ج)
# x(t) & =\xi\{\sin (4 \pi) u(t)\} \\د)
# x(t) & =\sum_{n=-\infty}^{+\infty} e^{-(2 t-n)}
# ه(\end{aligned}
# $$
#
# حل
#
# الف) يريوديک ، $2 \pi / 4=2 \pi$ = تناوب
# ب)$N=2 \pi / \pi=2$ ، بيريوديك
#
# تناوب $=\frac{2 \pi}{4 \pi}=1 / 2$ : $x(t)=\cos (4 n t) / 2$ (。
#
# و) پريوديك نيست.

# %% [markdown]
# 6) تعيين كنيد آيا سيگنالهاي گسسته در زمان زير متناوب اند يانه . در صورت متنـاوب بـودن د وره
# تناوب اصلي آنها را تعيين كنيد$x[n]=\sin \left[\frac{6 \pi}{7} \pi+1\right]$ (الف
# $x[n]=\cos \left(\frac{\pi}{8}-\pi\right)(ب$
# $x[n]=\cos \left[\frac{\pi}{8} \pi^2\right]$ (そ

# %% [markdown]
# $$
# \begin{array}{r}
# x[n]=\cos \left[\frac{\pi}{2} n\right] \cos \left[\frac{\pi}{4} \pi\right] \\
# x[n]=2 \cos \left[\frac{\pi}{4} n\right]+\sin \left[\frac{\pi}{8} n\right]-2 \cos \left[\frac{\pi}{2} n+\frac{\pi}{6}\right]
# \end{array}
# $$

# %% [markdown]
# حل
# الف) پريوديك با پريود -7
# ب) غير پريوديك .
# ج) پريوديك با پريود -8
# د)  تناوب دوره با متناوب 8
# هـ) متناوب با دوره تناوب 1

# %% [markdown]
# 7) در اين فصل چ ند خاصيت عمومي سيستمها را معرفي كرديم . سيـستم مـي توانـد صـفات زيـر
# راداشته يا نداشته باشد .
# ) 1( بدون حافظه
# ) 2( تغييرناپذير با زمان
# ) 3( خطي
# ) 4( علّي
# ) 5( پايدار
# تحقيق كنيد كه سيستمهاي پيوسته در زمان زير كدام يك از اين خواص را دارند و كدام يك را نـدارد

# %% [markdown]
# $$
# \begin{aligned}
# & y(t)=[(\cos 3 t)] x(t) \\
# & y(t)=x(t-2)+x(2-t) \text {  } \\
# & y(t)=\int_{-\infty}^{2 t} x(\tau) d \tau(\tau \\
# & (y t)=\left\{\begin{array}{ll}
# 0 & , x(t)<0 \\
# x(t)+x(t-2) & , x(t) \geq
# \end{array} \leftrightarrow \Delta\right. \\
# & y(t)=\left\{\begin{array}{ll}
# 0 & , t<0 \\
# x(t)+x(t-2), & t \geq 0
# \end{array}\right. \text { (2 } \\
# & y(t)=\frac{d x(t)}{d t} \\
# & y(t)=x(t / 3) \text {, }
# \end{aligned}
# $$

# %% [markdown]
# الف) خطي پايدار
# ب) بي حافظه، خطي، كازال؛ پايدار
# ج) خطي
# د) تغير ناپذير با زمان، خطي، كازال پايدار
# هـ) خطي، پايدار
# و) تغييرناپذير با زمان، خطي، كازال

# %% [markdown]
# 8) تحقيق كنيد كه كدام يك از خواص بيان شده در مسئله 1- 27 براي سيستمهاي گسسته در زمـان
# زير وجود دارند. دليل بياوريد. در هر مورد[n[y خروجي و[n[x ورودي سيستم است

# %% [markdown]
# $$
# \begin{array}{rlr}
# y[n]= & x[n-2]-2 x[n-8]( & y[n]=x[-n]) \\
# & \xi\{x[n-1]\}(2 & y[n]=n x[n]
# \end{array}(\xi
# $$

# %% [markdown]
# حل
# الف) خطي، پايدار
# ب) تغييرناپذير با زمان، خطي، كازال، پايدار
# ج) بي حافظه، خطي، كازال
# ) د خطي، پايدار
# هـ) خطي، پايدار
# و) بي حافظه، خطي، كازال، پايدا

# %% [markdown]
#  (الف) نشان دهيد سيستم گسـسته در زمـا ن داراي ورودي[n[x ، خروجـي [n[y و رابطـه ورودي ـ
# خروجــــي {[ ] } = [ ] n x Re n y جمــــع پذيرســــت. آيــــا ايــــن سيــــستم بــــه ازاي
# [yn] {e x[n]}رابطه j 4/ Re π
# = جمع پذيرست؟

# %% [markdown]
# ب) خطي بودن يك سيستم مستلزم اين است كه سيستم دو خاصيت جمـع پـذير و همگنـي را داشـته
# باشد. تحقيق كنيد هر يك از سيستمهاي زير خاصيت جمع پذيري و يا همگني را دارنـد يـا نـه . دليـل
# بياوريد، يعني براي اثبات وجود هر خاصيت برهان بياوريد و براي رد آن مثال نقض بيان كنيد

# %% [markdown]
# $$
# y[n]=\left\{\begin{array}{cc}
# \frac{x[n] x[n-2]}{x[n-1]} & , x[n-1] \neq \circ \\
# \circ & , x[n-1]=\circ
# \end{array}\right\}
# $$
#
#
# $$
# y(t)=\frac{1}{x(t)}\left[\frac{d x(t)}{d t}\right]
# $$
#
#
#
# $$
# n_1[n] \xrightarrow{s_1 0} y_1[n]=\operatorname{Re}\left\{x_1[n], n_2[n] \xrightarrow{s} y_2[n]=\operatorname{Re}\left\{x_2[n]\right\}\right.
# $$
#
#
#
# $$
# x_3[n]=x_1[n]+x_2[n]
# $$
#
#
#
# $$
# \begin{aligned}
# y_3[x] & =\operatorname{Re}\left\{x_3[n]\right\} \\
# & =\operatorname{Re}\left\{x_1[n]+x_2[n]\right\} \\
# & =\operatorname{Re}\left\{x_1[n]\right\}+\operatorname{Re}\left\{x_2[n]\right\} \\
# & =y_1[n]+y_2[n]
# \end{aligned}
# $$
#
#
# $x_1[n] \xrightarrow{s} y_1[n]=\operatorname{Re}\left\{e^{j \pi / 4} x_1[n]\right\}$
#
# $$
# x_2[n] \xrightarrow{s} y_2[n]=\operatorname{Re}\left\{e^{j \pi / 4} x_2[n]\right\}
# $$
#
# $$
# \begin{aligned}
# & y_3[n]=\operatorname{Re}\left\{e^{j \pi / 4} x_3[n]\right\} \\
# & =\cos (\pi n / 4) \operatorname{Re}\left\{x_3[n]\right\}-\sin (n \pi / 4) I_m\left\{x_3[n]\right\}
# \end{aligned}
# $$

# %% [markdown]
# $$
# \begin{gathered}
# +\cos (n \pi / 4) \operatorname{Re}\left\{x_1[n]\right\}-\sin (n \pi / 4) I_m\left\{x_1[n]\right\} \\
# +\cos (n \pi / 4) \operatorname{Re}\left\{x_2[n]\right\}-\sin (n \pi / 4) I_m\left[x_2[n]\right. \\
# =\operatorname{Re}\left\{e^{j n / 4} x_1[n]\right\}+\operatorname{Re}\left\{e^{j \pi / 4} x_2[n]\right\} \\
# =y_1[+n]+y_2[n]
# \end{gathered}
# $$
#
#
# بنابراين نتيجه چ سِستم جمع پذير نِسِت
# ب) (i) دو سيگنال ورودى را به صورت زير در نظر بگیرید:
#
# $$
# x_1(t) \xrightarrow{s} y_1(t)=\frac{1}{x(t)}\left[\frac{d_1 x_1(t)}{d t}\right]^2, x_2(t) \xrightarrow{s} y_2(t)=\frac{1}{x_1(t)}\left[\frac{d_2 x(t)}{d t}\right]^2
# $$
#
#
# حال سيكنال سوم را به صورت $x_3(t)=x_1(t)+x_2(t)$
#
# $$
# \begin{aligned}
# y_3(t) & =\frac{1}{x_3(t)}\left[\frac{d x_3(t)}{d t}\right]^2 \\
# & =\frac{1}{x_1(t)+x_2(t)}\left[\frac{d x_1(t)+d x_2(t)}{d t}\right]= \\
# & \neq y_1(t)+y_2(t)
# \end{aligned}
# $$
#
#
# بنابراين نتيجه مى گيريم كد هستقيم جمع بذير نيست
# حال ورودى چهارم را بي صورت $x_4(t)=a x_1(t)$ در نظر بكيريد. خروجى متناظر به صورت
#
# $$
# y_4(t)=\frac{1}{x_4(t)}\left[\frac{d x_4(t)}{d t}\right]^2=\frac{1}{\alpha x_1(t)}\left[\frac{d \alpha x_1(t)}{d t}\right]^2=\frac{a}{x_i(t)}\left[\frac{n_1 d(t)}{d t}\right]^2=\alpha y_1(t)
# $$
#
#
# بنابر اين همگن است.
#
# فرض كنيم
#
# $$
# \begin{gathered}
# x_1[n]=2 \delta[n+2]+2 \delta[n+1]+2 \delta[n] \\
# x=[2]=\delta[n+2]+2 \delta[n+1]+3 \delta[n] \\
# \vdots \\
# y_1[0]=2 \quad, \quad y_2[0]=3 / 2
# \end{gathered}
# $$

# %% [markdown]
# $$
# \begin{gathered}
# +\cos (n \pi / 4) \operatorname{Re}\left\{x_1[n]\right\}-\sin (n \pi / 4) I_m\left\{x_1[n]\right\} \\
# +\cos (n \pi / 4) \operatorname{Re}\left\{x_2[n]\right\}-\sin (n \pi / 4) I_m\left[x_2[n]\right] \\
# =\operatorname{Re}\left\{e^{j n / 4} x_1[n]\right\}+\operatorname{Re}\left\{e^{j \pi / 4} x_2[n]\right\} \\
# =y_1[+n]+y_2[n]
# \end{gathered}
# $$
#
#
# بنابراين نتيجه مى گيريم كد سيستم جمع پذير نيست.
# ب) (i) دو سيكال ورودى را به صورت زير در نظر بگیرید:
#
# $$
# x_1(t) \xrightarrow{s} y_1(t)=\frac{1}{x(t)}\left[\frac{d_1 x_1(t)}{d t}\right]^2, x_2(t) \xrightarrow{s} y_2(t)=\frac{1}{x_1(t)}\left[\frac{d_2 x(t)}{d t}\right]^2
# $$
#
#
# حال سيكّنال سوم را بصورت $x_3(t)=x_1(t)+x_2(t)$ خروجى منتاظر سِستم عبارتست از:و
#
# $$
# \begin{aligned}
# y_3(t) & =\frac{1}{x_3(t)}\left[\frac{d x_3(t)}{d t}\right]^2 \\
# & =\frac{1}{x_1(t)+x_2(t)}\left[\frac{d x_1(t)+d x_2(t)}{d t}\right]= \\
# & \neq y_1(t)+y_2(t)
# \end{aligned}
# $$
#
#
# بنابر اين نتيجه مى گيريم كد هستقيم جمع بأدير نيست
# حال ورودى چهارم را بهورت $x_4(t)=a x_1(t)$ در نظر بكيريد. خروجى متناظر به صورت
#
# $$
# y_4(t)=\frac{1}{x_4(t)}\left[\frac{d x_4(t)}{d t}\right]^2=\frac{1}{\alpha x_1(t)}\left[\frac{d \alpha x_1(t)}{d t}\right]^2=\frac{a}{x_i(t)}\left[\frac{n_1 d(t)}{d t}\right]^2=\alpha y_1(t)
# $$
#
#
# بنابر اين سيستم همكُن است.
# سمستم جمع بذير نيست. مثال زير را در نظر مى گيريم.م (ii
# فرض كنيم
#
# $$
# \begin{aligned}
# & x_1[n]=2 \delta[n+2]+2 \delta[n+1]+2 \delta[n] \\
# & x=[2]=\delta[n+2]+2 \delta[n+1]+3 \delta[n]
# \end{aligned}
# $$
#
#
# خروجى متناظر در $n=0$ برابر است با:
#
# $$
# y_1[0]=2 \quad, \quad y_2[0]=3 / 2
# $$

# %% [markdown]
# حال سيُكال را بهورت
#
# $$
# \begin{aligned}
# x_3^{-}[n] & =x_1[n]+x_2[n] \\
# & =3 \delta[n+2]+4 \delta[n+1]+5 \delta[n]
# \end{aligned}
# $$
#
#
# در نظر بكيريد.
#
# نُشان مى دهد كه سِستم جمع بأدير نيست.
#
# $$
# y_4[n]=\left\{\begin{array}{lc}
# \frac{x_4[n] x_4[n-2]}{x_4[n-1]} x_4[n-1] \neq 0 & \\
# 0 & \text { ساير نقاط }
# \end{array}=a y_4[n]\right.
# $$
#
#
# سيستم همگن است.

# %% [markdown]
#  تحقيق كنيد هر يك از سيستمهاي زير وارونپذيرند يا نه . در صورت وارو نپـذير بـودن سيـستم
# وارون راپيدا كنيد. در غير اين صورت دو سيگنال مختلف بيابيد كه پاسخ سيستم به آنها يكي باشد
# $$
# \begin{gathered}
# y(t)=\cos [x(t)] \\
# y(t)=\int_{-\infty}^t x(\tau) d \tau
# \end{gathered}
# $$
#
#
# $$
# y(t)=x(t-4)
# $$
#
#
# $$
# \begin{aligned}
# & y[n]=n x[n] C_C \\
# & x[n]=\left\{\begin{array}{ll}
# x[n-1], & n \geq 1 \\
# 0, & n=0 \\
# x[n], & n \leq-1
# \end{array} \Leftrightarrow\right. \\
# & y[n]=x[1-n](; \quad y[n]=x[n] x[n-1] \text {, } \\
# & y(t)=\int_{-\infty}^t e^{-(t-\tau)} x(\tau) d \tau(\dot{\tau} \\
# & y[n]=\sum_{k=-\infty}^n\left(\frac{1}{2}\right)^{n-k} x[k](b \\
# & y(t)=\frac{d x(t)}{d t}(\varsigma \\
# & y(t)=x(2 t)\left(\mathcal{J}[n]=\left\{\begin{array}{ll}
# x[n+1] & , n \geq 0 \\
# x[n] & , n \leq-1
# \end{array} \text { ( } s\right.\right. \\
# & y[n]=x[2 n]
# \end{aligned}
# $$

# %% [markdown]
#  الف) تغييرناپذير، معكوس پذير: (4 + t(x) = t(y .
# 1x خروجي هاي يكساني را مي دهند .
# (t) = x(t)+ 2π و x(t) سيگنالهاي ،پذير تغيير) ب
# ج) تغيير پذير، [n [sδ,]n [δ خروجي هاي يكساني را مي دهند. ( )
# ( )
# dt
# dx t
#  . y t =
# ) د تغييرناپذير، معكوس پذير .
#  براي پذير؛ معكوس ،تغييرناپذير هـ)
# ) و تغييرپذير،  نتايج يكساني را ارائه مي كنند .
# ) ذ تغييرناپذير، معكوس پذير،
# خ) تغييرناپذير، معكوس پذير، ( ) ( )
# ط) تغييرناپذير، معكوس پذير،
# 2
# ي) تغييرپذير، اگر (t(x هر ثابت دلخواهي فرض شود، در اين صورت
# ك) تغييرپذير، [ نتايج يكساني  را ارائه مي دهند .
# ل) تغييرناپذير، معكوس پذير، ( ) ( )
#
# ) م تغييرناپذير، معكوس پذير: ( ) ( )

# %% [markdown]
# 1) در اين مثال يكي از مهمترين نتايج خواص خطي بودن و تغييرناپـذيري بـا زمـان را نـشان مـي
# دهيم، يعني اين كه اگر پاسخ سيستم خطي تغييرناپذير با زمان (LTI (به يك ورودي يـا چنـد ورودي
# را بدانيم، مي تواني پاسخ سيستم به وروديهاي متعدد ديگري را نيز حساب كنيم . قسمت اعظم بقيه اين
# كتاب به كاربرد اين حقيقت در پي ريزي روشهايي براي تحليـل و سـنتز سيـستمهاي LTI اختـصاص
# دارد

# %% [markdown]
#  الف) يك سيستم LTI در نظر بگيريد كه پاسخ آن به سـيگنال (t (x
#  شـكل م 1- ( 31 الـف ) سـيگنال
# y (t) 1
# 2 شكل م 1- (31 ب) است. پاسخ سيستم بـه ورودي (t (x
#  شـكل م 1- ج (31 ) را تعيـين و بـه
# دقت رسم كنيد .
# 3x شكل م 1- ) د (31 تعيين و رسم كنيد .
# ب) پاسخ سيستم مفروض در قسمت الف را به ورودي(t(

# %% [markdown]
# ![ئههه.png](data:image/png;base64,...)

# %% [markdown]
# 2) فرض كنيد (t(x يك سيگنال پيوسته در زمان است و فرض كنيد كه
# y (t) x(2t) y2
# (t) = x(t 2/ ) و 1=
# y (t)سيگنال 1
# نوع سريع شده (t(x است، از اين لحاظ كه زمان لازم براي ايجاد هر قسمت آن نـصف
# 2 شده است . به طور مشابه، (t (y
# گونه ي كند شدة (t(x است، زيـرا مـدت آن دو برابـر شـده اسـت .
# گزاره هاي زير را در نظر بگيريد :
# 1 نيز متناوب است ) 1( اگر (t(x متناوب باشد، آنگاه(t (y
# .
# y (t)اگر( 2)
# 1
#  متناوب باشد، آنگاه (t(x نيز متناوب است .
# 2 نيز متناوب است ) 3( اگر (t(x متناوب باشد، آنگاه (t (y
# .
# y (t)اگر( 4)
# 2
#  متناوب باشد، آنگاه (t(x نيز متناوب است .
# درستي يا نادرستي هر يك از اين گزاره ها را تحقيق كنيد . در صورت درست بودن يك گـزاره، رابطـه
# بين زمان تناوب اصلي د و سيگنال ذكر شده در گزاره را بيان كنيد. در صـورت نادرسـت بـودن گـزاره،
# مثال نقض بياو .ريد
# حل :
# تمامي گزاره ها صحيح است .
# y (t) .است متناوب ،T تناوب با x(t) 1 (
# 1
# 2 ، با تناوب
# T پريوديك است .
# y (t) 2 (
# 1
#  با تناوب T متناوب است، (t(x با تناوب T2 پريوديك است .
# ) 3 (t(x متناوب با دوره تناوب T و (t (y
# L
#  با دوره تناوب T2 پريوديك است .
# 2 و (t(x با دوره تناوب 2 متناوب با دوره تناوب T ( 4) t (y
# T پريوديك است

# %% [markdown]
# 33) فرض كنيد[n[x يك سيگنال گسسته در زمان باشد و
#
# 2
#
# y [n]سيگنالهاي 1
# y [n] و 2
#  به ترتيب گونه هاي سريع شده و كند شده [n[x هستند . البته بايـد توجـه
# داشته باشيد كه در حالت گسسته در زمان ، نوع هاي سريع شده و كند شده با همتاهاي پيوسته در زمان
# خود تفاوتهاي عمده اي دارند. گزاره هاي زير را در نظر بگيرد .
# 1 نيز متناوب است ) 1( اگر[n[x متناوب باشد، آنگاه[n [y
# .
# y [n]اگر( 2)
# 1
#  متناوب باشد، آنگاه[n[x نيز متناوب است

# %% [markdown]
# $$
# y_2[n]=\left\{\begin{array}{ll}
# x[n / 2] & \text { زوج } n \\
# 0 & \text { فرد } n
# \end{array} \quad, \quad y_1[n]=x[2 n]\right.
# $$

# %% [markdown]
# ( اگر[n[x متناوب باشد، آنگاه[n [y
# .
# y [n]اگر( 4)
# 2
#  متناوب باشد، آنگاه[n[x نيز متناوب است .
# درستي يا نادرستي هر يك ا ز اين گزاره ها راتعيين كنيد . در صورت درست بودن يك گزاره، رابطه بين
# زمان تناوب پايه دو سيگنال را بيان كنيد. در صورت نادرست بودن گزاره مثال نقض بزنيد .

# %% [markdown]
# حل:
# 1.صخیح
# 2.غلط
# 3.صحیح
# 4.صحیح

# %% [markdown]
# درستی و یا نادرستی را تایین کنید:

# %% [markdown]
#  $y_1[n]=x[2 n]$ $N_{\circ}=2 N \circlearrowleft x[n+N]=x[n] ; y_2\left[n+N_{\circ}\right]=y_2[n]$, $\lambda(r$ $N_{\mathrm{o}}=N / 2$ 。S $y_2[n+N]=y_2[n] ; x\left[n+N_{\mathrm{o}}\right]=x[n]$. (\& الف)  [n] فرد باشْد، آنگاه:
#
# $$
# \sum_{n=-\infty}^{+\infty} x[n]=0
# $$
#  $x_o[n]=\vartheta_d\{x[n]\} \quad, \quad x_e[n]=\xi\{x[n]\}$نـّـان دهيد كي
#
# $$
# \sum_{n=-\infty}^{+\infty} x^2[n]=\sum_{n=-\infty}^{+\infty} x_e^2[n]+\sum_{n=-\infty}^{+\infty} x_o^2[n]
# $$
#  براى حالت پيوسته در زمان صادق است. ثابت كنید كه
#
# $$
# \int_{-\infty}^{+\infty} x^2(t) d t=\int_{-\infty}^{+\infty} x_e^2(t) d t+\int_{-\infty}^{+\infty} x_o^2(t) d t
# $$

# %% [markdown]
# زوج باشُد و N فرد باشُد.
# : بريوديك است امتا، $y_1[n]=x[2 n]$ $N_{\circ}=2 N \circlearrowleft x[n+N]=x[n] ; y_2\left[n+N_{\circ}\right]=y_2[n]$, $\lambda(r$ $N_{\mathrm{o}}=N / 2$ 。S $y_2[n+N]=y_2[n] ; x\left[n+N_{\mathrm{o}}\right]=x[n]$. (\& الف) نشان دهيد كه اكر [n] فرد باشْد، آنگاه:
#
# $$
# \sum_{n=-\infty}^{+\infty} x[n]=0
# $$
#  $x_o[n]=\vartheta_d\{x[n]\} \quad, \quad x_e[n]=\xi\{x[n]\}$ نشان دهيد که
#
# $$
# \sum_{n=-\infty}^{+\infty} x^2[n]=\sum_{n=-\infty}^{+\infty} x_e^2[n]+\sum_{n=-\infty}^{+\infty} x_o^2[n]
# $$
#  براى حالت پيوسته در زمان صادق است. ثابت كيْد كه
#
# $$
# \int_{-\infty}^{+\infty} x^2(t) d t=\int_{-\infty}^{+\infty} x_e^2(t) d t+\int_{-\infty}^{+\infty} x_o^2(t) d t
# $$

# %% [markdown]
# كه در آن ( $x(t), x_e$
# v
# الف) فرض كنيل:
#
# $$
# \sum_{n=s-\infty}^{\infty} x[n]=x[0]+\sum_{n=1}^{\infty}\{x[n]+x[-n]\}
# $$
#
#
# ب) فرض كنيد
#
# $$
# y[-n]=x_1[-n] x_2[-n]=-x_1[n] x_2[n]=-y[n]
# $$
#
#
# اين نشان مى دهد ك، [n] فرد است. ج) فرض كنيل:
#
# $$
# \begin{aligned}
# \sum_{n=-\infty}^{+\infty} x^2[n] & =\sum_{n=-\infty}^{+\infty}\left\{x_e[n]+x_o[n]\right\}^2 \\
# & =\sum x_e^2[n]+\sum_{n=-\infty}^{t^{-}} x_{\circ}^2[n]+2 \sum_{n=-\infty}^{t^{-}} x_e[n] x_{\circ}[n]
# \end{aligned}
# $$
#
#
# $$
# 2 \sum_{n=-\infty}^{+\infty} x_e[n] x_o[n]=0
# $$
#
#
# بنابراين:
#
# $$
# \sum_{n=-\infty}^{+\infty} x^2[n]=\sum_{n=-\infty}^{+\infty} x_e^2[n]+\sum_{n=-\infty}^{+\infty} x_o^2[n]
# $$
#
#
# د)فرض كنيد:
#
# $$
# \int_{-\infty}^{+\infty} x^2(t) d t=\int_{-\infty}^{+\infty} x_o^2(t) d t+\int_{-\infty}^{+\infty} x_e^2(t)+2 \int_{-\infty}^{+\infty} x_o(t) x_e(t) d t
# $$
#
#
# $$
# \int_{-\infty}^{+\infty} x_s(t) x_e(t) d t=0
# $$
#
#
# بنابراين:

# %% [markdown]
# $$
# \begin{aligned}
# &\int_{-\infty}^{+\infty} x^2(t) d t=\int_{-\infty}^{+\infty} x_e^{e 2}(t) d t+\int_{-\infty}^{+\infty} x_0^2(t) d t\\
# &
# \end{aligned}
# $$

# %% [markdown]
# 1,35) فرض كنيد رابطه زير سيگنال نمايي گسسته در زمان متناوب باشد
#
# $$x[n]=e^{j m(2 \pi / N) n}$$
# (m,N) .م .م/ ب  = N
# كه(N,m (ب م م بزرگترين مقسوم عليه مشترك m, N است

# %% [markdown]
# ![درن.png](data:image/png;base64,...)

# %% [markdown]
# ١٫٣٦) فرض کنید (f)،× سیگنال نمایی مختلط پیوسته در زمان زير باشد
# e^jmot
# کہ فرکانس پایه آن ۔۵ و دوره تناوب پایہ آن @/27=[T[n است. سیگنال گسسته در زمان را در
# نظر بگیرید که با گرفتن نمونه های هم فاصله (x(t به دست می آید، یعنی
# x[n]=x(nt)=e"j°nT
# الف) نشان دهيد كه [x[n فقط وفقط به شرطى متناوبخواهد بود كه .7/T عدد گويا باشد، به عبارت
# دیگر اگر و تنها اگر مضربی از فاصله نمونه گیری دقیقاً برابر مضربی از دورہ تناوب (x(t باشد.

# %% [markdown]
# $$
# \frac{2 \pi}{q}(ب, p)(p, q)=\frac{2 \pi}{p} \frac{p}{q} \operatorname{gcd}(p, q)=\frac{\omega_0}{P} \operatorname{gcd}(p, q)=\frac{\omega_T T}{p} \operatorname{gcd}(p, q)
# $$
#
# . $x(t)$ قناوب هاى $\frac{p}{\operatorname{gcd}(p, q)}$ (飞)
# $$
# \Phi_{x y}(t)=\int_{-\infty}^{+\infty} x(t+\tau) y(t) d \tau
# $$

# %% [markdown]
# ,38) در اين مسئله به بررسي برخي خواص تابع ضربه واحد مي پردازيم .
# الف) نشان دهيد كه
#
# را بررسي كنيد (شكل 1- 34 را ببينيد ).
# ∆ δ تعريـف كـرديم . در
# ب) در بخش 1-4 ضربه واحد پيوسته در زمان را به صورت حد سـيگنال (t(
# ∆ δ بيان كرديم . مـثلاً چـون سـيگنال بـه پلـه
# حقيقت، چند خاصيت (t (δ را با بررسي خواص متناظر
# واحد ميل مي كند .
#
# حد
# يعني فرض مي كنيم (t (δ مشتق(t(u باشد .
# در واقع به جاي مشخص كردن مقدار (t (δ به ازاي مقادير مختلف t، كه كاري ناممكن است، اين تابع
# را با خواص آن تعريف كنيم . در فصل 2 يكي از مشخصه هاي بسيار ساده رفتار تـابع ضـربه واحـد را
# مطرح مي كنيم . حال مي خواهيم اين مطلب را بيان كنيم كه مفهوم اصلي در اسـتفاده از ضـربه واحـد،
# فهم چگونگي رفتار آن است . براي اين كار شش سيگنال شكل م 1- 38 را در نظر بگيريد . نشان دهيـد
# كه تمام اينها به ازاي  → ∆ (به صورت ضربه به رفتار مي كنند

# %% [markdown]
# $$
# \begin{gathered}
# u_{\Delta}(t)=\int_{-\infty}^t \delta_{\Delta}(\tau) d \tau \\
# u(t)=\downarrow u_{\Delta}(t)
# \end{gathered}
# $$

# %% [markdown]
# ![kjkjkjkj.png](data:image/png;base64,...)

# %% [markdown]
# 40 الف ) نشان دهيد اگر يك س يستم يا جمع پذ ير باشد يا همگن ، به ازاي ورودي متحـد بـا صـفر،
# خروجي متحد با صفر بدست مي دهد .
# ب) سيستمي (پيوسته يا گسسته در زمان ) تعيين كنيد كه نه جمع پذير باشد و نه همگن، ولـي بـه ازاي
# ورودي متحد با صفر خروي متحد با صفر ايجاد كند .
# t و
# 1
# ج) با توجه به بند (الف) آيا مي توان نتيجه گر فت كه اگر ورودي يك سيستم خطي بين زمانهـاي
# 2
# 1n t در حال پيوسته در زمان يا بين
# 2n و .
#  در حالت گسسته در زمان صفر باشد، خروجي نيـز بايـد
# در آن فاصله صفر باشد؟ توضيح دهيد .
#  :حل
#  الف) اگر يك سيستم جمع پذير باشد در اينصورت :
#  = x(t) − x(t)→ y − y(t) =
# ب) بعنوان يك سيستم مي باشد .
# y(t) x (t)

# %% [markdown]
# ٤٤
#  الف) گزاره زير درست است يا نادرست؟
# اتصال سري دو سيستم خطي تغييرناپذير با زمان، سيستمي خطي و تغييرناپذير بـا زمـان اسـت . پاسـخ
# خود را با دليل بيان كنيد .
# ب) گزاره زير درست است يا نادرست؟
# اتصال سري دو سيستم غيرخطي يك سيستم غيرخطي است. پاسخ خود را با دليل بيان كنيد .
# ج) سه سيستم با روابط ورودي ـ خروجي زير در نظر بگيريد

# %% [markdown]
# ![klklklklklklk.png](data:image/png;base64,...)

# %% [markdown]
# ![huhuhuhu.png](data:image/png;base64,...)

# %% [markdown]
# ١٫٤٦) سیستم فیدیک دار شكل ١-٤٦ را در نظر بگيريد وفرض كنيد كه به ازاى ٥>n
# داريم ٥=[y[n
# الف) خروجى را به ازاى [x[n]=5[n رسم كنيد
# ب) [x[n]= u[n باشد، خروجى رارسم كنيد.

# %% [markdown]
# ![99999999999999.png](data:image/png;base64,...)

# %% [markdown]
# ![8888888888.png](data:image/png;base64,...)

# %% [markdown]
# 7) الف ) فرض كنيد كه S يك سيستم نمواً خطي، [n [x
# 1 يـك سـيگنال ورودي دلخـواه، و [n [y
# خروجي متناظر با آن است . سيستم شكل م 1- (47 الف) را در نظر بگيريد . نشان دهيد كه اين سيـستم
# 1x بـستگي
# خطي مي باشد و در واقع رابطه كلي ورودي ـ خروجي بين [n[x و[n[y به انتخـاب [n[
# ندارد .
# ب) با استفاده از قسمت (الف) نشان دهيد كه S را مي توان به صورت شكل 1- 48 نمايش داد .
# ج) كدام يك از سيستمهاي زير نمواً خطي است؟ پاسخ خود را با دليل بيان كنيد و اگر سيـ ستمي نمـواً
# y آن را بـراي نمـايش س يـستم بـه
# (t) يـا y
# خطي است، سيستم خطي L و پاسخ ورودي صـفر [n[
# صورت شكل 1- 48 بيابيد

# %% [markdown]
# $$
# \begin{aligned}
# &\text { صورت شكل 1-1 ي بیابید. }\\
# &\begin{gathered}
# y[n]=n+x[n]+2 x[n+4] \\
# y[n]=\left\{\begin{array}{l}
# n / 2 \\
# (n-1) /\left(1+\sum_{k=-\infty}^{(n-1) / 2} x[k]\right)
# \end{array}\right. \\
# y[n]= \begin{cases}x[n]-x[n-1]+3 & , x[0] \geq 0 \\
# x[n]-x[n-1]-3 & , x[0]<0\end{cases}
# \end{gathered}
# \end{aligned}
# $$

# %% [markdown]
# حل
# 1 الف) { پاسخ سيستم به [n [x
# (x[n]) x [n] به سيستم پاسخ} - { + 1
# }= پاسخ كلي سيستم شكل -م (47 الف )
#
# 1 + ({ پاسخ ورودي صفر سيستم + پاسخ يك سيستم خطي L به [n [x]) n[x(
#  ={
#
# 1 {پاسخ يك سيستم خطي L به ورودي (پاسخ صفر سيستم +[n [x
# ({-
#
#  { پاسخ يك سيستم خطي L به [n [x =

# %% [markdown]
# ![عععععععععععععععععع.png](data:image/png;base64,...)

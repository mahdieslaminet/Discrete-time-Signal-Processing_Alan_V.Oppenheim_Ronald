# %% [markdown]
# # 🧪 آزمون ۱۰ سؤاله DSP
#
# در این آزمون ۱۰ سؤال چهارگزینه‌ای از مباحث مهم پردازش سیگنال‌های دیجیتال آورده شده است. گزینه صحیح در انتهای هر سؤال با علامت ✅ مشخص شده است.
#
# ---
#
# ### 1. خروجی سیستم زیر کدام است؟
# **سیستم:**  \( y[n] = x[n] - x[n-1] \)
#
# - a) انتگرال تفاضلی
# - ✅ b) مشتق تفاضلی
# - c) تأخیر
# - d) میانگین متحرک
#
# ---
#
# ### 2. اگر \( x[n] = \cos\left(\frac{\pi}{3}n\right) \)، فرکانس نرمالایز آن چیست؟
#
# - ✅ a) $$( \frac{1}{3} )$$
# - b) $$( \frac{\pi}{3} )$$
# - c) $$( frac{2}{3} )$$
# - d) $$( pi )$$
#
# ---
#
# ### 3. سیستم \( y[n] = x[2n] \) چه نوع سیستمی است؟
#
# - a) خطی و تغییرناپذیر نسبت به زمان
# - ✅ b) غیرخطی و تغییرپذیر نسبت به زمان
# - c) خطی و تغییرپذیر نسبت به زمان
# - d) غیرخطی و تغییرناپذیر نسبت به زمان
#
# ---
#
# ### 4. مقدار DFT سیگنال $$( x[n] = \delta[n] )$$ با طول ۴ چیست؟
#
# - a) [1, 0, 0, 0]
# - ✅ b) [1, 1, 1, 1]
# - c) [4, 0, 0, 0]
# - d) [0, 0, 0, 1]
#
# ---
#
# ### 5. پاسخ فرکانسی فیلتر FIR خطی فاز چه خاصیتی دارد؟
#
# - a) دامنه و فاز ثابت
# - ✅ b) فاز خطی
# - c) دامنه متغیر ولی فاز ثابت
# - d) فقط دامنه ثابت
#
# ---
#
# ### 6. اگر سیستمی دارای تابع تبدیل
# $$( H(z) = \frac{1}{1 - 0.5z^{-1}} )$$
# باشد، سیستم پایدار است اگر:
#
# - ✅ a) \( |z| > 0.5 \)
# - b) \( |z| < 0.5 \)
# - c) \( |z| = 0.5 \)
# - d) همیشه ناپایدار است
#
# ---
#
# ### 7. نرخ نمونه‌برداری مورد نیاز طبق قضیه نایکوئیست برای سیگنالی با حداکثر فرکانس ۵ کیلوهرتز چیست؟
#
# - a) 5 kHz
# - ✅ b) 10 kHz
# - c) 2.5 kHz
# - d) 1 kHz
#
# ---
#
# ### 8. تبدیل فوریه گسسته (DTFT) تابع \( \delta[n] \) چیست؟
#
# - a) 0
# - ✅ b) 1
# - c) $$( e^{-j\omega} ) $$
# - d)$$ ( \delta(\omega))$$
#
# ---
#
# ### 9. کدام یک از گزینه‌های زیر فیلتر پایین‌گذر (Low-pass) است؟
#
# - ✅ a)$$( H(e^{j\omega}) = \begin{cases}1 & |\omega| < pi/4 \\ 0 & \text{else}\end{cases})$$
# - b)$$( H(e^{j\omega}) = \delta[n] )$$
# - c) $$( H(e^{j\omega}) = e^{j\omega} )$$
# - d) $$( H(e^{j\omega}) = \cos(\omega) $$
#
# ---
#
# ### 10. یکی از روش‌های طراحی فیلتر دیجیتال IIR چیست؟
#
# - a) پنجره‌گذاری (Windowing)
# - b) روش فرکانس نمونه‌برداری شده
# - ✅ c) تطابق تبدیل‌های آنالوگ به دیجیتال
# - d) تخمین طیفی

# %% [markdown]
# # 🧪 آزمون ۱۰ سؤاله DSP
#
# در این آزمون ۱۰ سؤال چهارگزینه‌ای از مباحث مهم پردازش سیگنال‌های دیجیتال آورده شده است. گزینه صحیح در انتهای هر سؤال با علامت ✅ مشخص شده است.
#
# ---
#
# ### 1. خروجی سیستم زیر کدام است؟
# **سیستم:**  \( y[n] = x[n] - x[n-1] \)
#
# - a) انتگرال تفاضلی
# - ✅ b) مشتق تفاضلی
# - c) تأخیر
# - d) میانگین متحرک
#
# ---
#
# ### 2. اگر \( x[n] = \cos\left(\frac{\pi}{3}n\right) \)، فرکانس نرمالایز آن چیست؟
#
# - ✅ a) \( \frac{1}{3} \)
# - b) \( \frac{\pi}{3} \)
# - c) \( \frac{2}{3} \)
# - d) \( \pi \)
#
# ---
#
# ### 3. سیستم \( y[n] = x[2n] \) چه نوع سیستمی است؟
#
# - a) خطی و تغییرناپذیر نسبت به زمان
# - ✅ b) غیرخطی و تغییرپذیر نسبت به زمان
# - c) خطی و تغییرپذیر نسبت به زمان
# - d) غیرخطی و تغییرناپذیر نسبت به زمان
#
# ---
#
# ### 4. مقدار DFT سیگنال \( x[n] = \delta[n] \) با طول ۴ چیست؟
#
# - a) [1, 0, 0, 0]
# - ✅ b) [1, 1, 1, 1]
# - c) [4, 0, 0, 0]
# - d) [0, 0, 0, 1]
#
# ---
#
# ### 5. پاسخ فرکانسی فیلتر FIR خطی فاز چه خاصیتی دارد؟
#
# - a) دامنه و فاز ثابت
# - ✅ b) فاز خطی
# - c) دامنه متغیر ولی فاز ثابت
# - d) فقط دامنه ثابت
#
# ---
#
# ### 6. اگر سیستمی دارای تابع تبدیل
# \( H(z) = \frac{1}{1 - 0.5z^{-1}} \)
# باشد، سیستم پایدار است اگر:
#
# - ✅ a) \( |z| > 0.5 \)
# - b) \( |z| < 0.5 \)
# - c) \( |z| = 0.5 \)
# - d) همیشه ناپایدار است
#
# ---
#
# ### 7. نرخ نمونه‌برداری مورد نیاز طبق قضیه نایکوئیست برای سیگنالی با حداکثر فرکانس ۵ کیلوهرتز چیست؟
#
# - a) 5 kHz
# - ✅ b) 10 kHz
# - c) 2.5 kHz
# - d) 1 kHz
#
# ---
#
# ### 8. تبدیل فوریه گسسته (DTFT) تابع \( \delta[n] \) چیست؟
#
# - a) 0
# - ✅ b) 1
# - c) \( e^{-j\omega} \)
# - d) \( \delta(\omega) \)
#
# ---
#
# ### 9. کدام یک از گزینه‌های زیر فیلتر پایین‌گذر (Low-pass) است؟
#
# - ✅ a) \( H(e^{j\omega}) = \begin{cases}1 & |\omega| < \pi/4 \\ 0 & \text{else}\end{cases} \)
# - b) \( H(e^{j\omega}) = \delta[n] \)
# - c) \( H(e^{j\omega}) = e^{j\omega} \)
# - d) \( H(e^{j\omega}) = \cos(\omega) \)
#
# ---
#
# ### 10. یکی از روش‌های طراحی فیلتر دیجیتال IIR چیست؟
#
# - a) پنجره‌گذاری (Windowing)
# - b) روش فرکانس نمونه‌برداری شده
# - ✅ c) تطابق تبدیل‌های آنالوگ به دیجیتال
# - d) تخمین طیفی

# %% [markdown]
# # 🧪 آزمون ساده – Discrete-Time Signals and Systems (20 سؤال)
#
# این مجموعه شامل سؤالات ساده و مفهومی برای درک بهتر سیگنال‌ها و سیستم‌های زمان گسسته است.
#
# ---
#
# ### 1. سیگنال \( x[n] = 3^n \) چه نوع سیگنالی است؟
#
# - a) دوره‌ای
# - ✅ b) نمایی
# - c) متناوب
# - d) ثابت
#
# ---
#
# ### 2. سیگنال $$( \delta[n] )$$ چه خاصیتی دارد؟
#
# - a) مقدار آن همیشه 1 است
# - b) همیشه صفر است
# - ✅ c) فقط در $$( n = 0 )$$ مقدارش 1 است
# - d) فقط در $$( n = 1 )$$ مقدارش 1 است
#
# ---
#
# ### 3. اگر $$( x[n] = u[n] )$$، مقدار $$( x[-2] )$$ چند است؟
#
# - a) 1
# - ✅ b) 0
# - c) -1
# - d) تعریف‌نشده
#
# ---
#
# ### 4. تابع پله واحد چیست؟
#
# - a) سیگنالی که از صفر تا بی‌نهایت صفر است
# - ✅ b) سیگنالی که برای \( n \geq 0 \) برابر 1 است
# - c) یک سیگنال نویز
# - d) سیگنالی با مقدار منفی
#
# ---
#
# ### 5. مقدار $$( \delta[n] * x[n] )$$ چیست؟
#
# - a) صفر
# - ✅ b) $$( x[n] )$$
# - c) $$( x[n+1] )$$
# - d) $$( x[n-1] )$$
#
# ---
#
# ### 6. عملیات $$( x[-n] )$$ چه کاری انجام می‌دهد؟
#
# - a) جابجایی به جلو
# - ✅ b) بازتاب در محور عمودی (آینه‌ای)
# - c) تأخیر زمانی
# - d) کشیدگی سیگنال
#
# ---
#
# ### 7. اگر $$( x[n] = 1 )$$ برای همه‌ی $$( n )$$، سیگنال چه نوعی است؟
#
# - a) تصادفی
# - b) پله‌ای
# - ✅ c) DC (ثابت)
# - d) نمایی
#
# ---
#
# ### 8. مجموع $$( \delta[n-2] + \delta[n+1] )$$ در چه مقادیری از n مقدار دارد؟
#
# - a) فقط در n = 0
# - b) در تمام n‌ها
# - ✅ c) در n = 2 و n = -1
# - d) فقط در n = 1
#
# ---
#
# ### 9. پاسخ ضرب کانولوشن سیگنال \( x[n] \) با \( \delta[n-k] \) چیست؟
#
# - a) $$( x[n+k] )$$
# - b) $$( x[n] * 0 )$$
# - ✅ c) $$( x[n-k] )$$
# - d) $$( x[n] + k )$$
#
# ---
#
# ### 10. کدام سیگنال زیر متناوب (periodic) نیست؟
#
# - a) $$( \cos(\pi n))$$
# - b) $$( \sin(\frac{2\pi n}{3}))$$
# - ✅ c) $$( 2^n )$$
# - d) $$( \cos(0) )$$
#
# ---
#
# ### 11. تابع \( u[n] - u[n-3] \) چه سیگنالی تولید می‌کند؟
#
# - a) سیگنال صفر
# - ✅ b) یک پالس با طول 3
# - c) سیگنال رو به رشد
# - d) نویز سفید
#
# ---
#
# ### 12. تأخیر سیگنال \( x[n] \) به اندازه ۴ واحد چگونه نوشته می‌شود؟
#
# - a) $$( x[n+4] )$$
# - ✅ b) $$( x[n-4])$$
# - c) $$( x[n] \cdot 4)$$
# - d) $$( x[4n])$$
#
# ---
#
# ### 13. اگر سیستمی خطی باشد، آنگاه:
#
# - a) خروجی همیشه برابر ورودی است
# - ✅ b) اصل جمع و همگنی برقرار است
# - c) تأخیر زمان ندارد
# - d) بازتاب در زمان دارد
#
# ---
#
# ### 14. خاصیت علیت یعنی:
#
# - a) پاسخ سیستم فقط به آینده بستگی دارد
# - ✅ b) پاسخ سیستم به گذشته و حال بستگی دارد
# - c) سیستم همیشه صفر است
# - d) فقط به ورودی‌های مثبت پاسخ می‌دهد
#
# ---
#
# ### 15. اگر \( x[n] = \cos(\omega_0 n) \)، دوره آن کی متناهی است؟
#
# - a) اگر $$( \omega_0 = \pi/2 )$$ باشد
# - ✅ b) اگر $$( \omega_0/2\pi )$$ یک عدد گویا باشد
# - c) اگر $$( \omega_0 = 0 )$$ باشد
# - d) همیشه متناهی است
#
# ---
#
# ### 16. کدام یک از موارد زیر سیستم LTI نیست؟
#
# - a) $$( y[n] = x[n] + 3x[n-1] )$$
# - ✅ b) $$( y[n] = x[n]^2 )$$
# - c) $$( y[n] = 2x[n] )$$
# - d) $$( y[n] = x[n+1] )$$
#
# ---
#
# ### 17. کدام گزینه تابع انتقال سیستم را نشان می‌دهد؟
#
# - a) $$( x[n] )$$
# - b) $$( y[n] )$$
# - ✅ c) $$( H(z) )$$
# - d) $$( \delta[n] )$$
#
# ---
#
# ### 18. اگر سیگنالی دارای دامنه نامتناهی باشد، چه ویژگی‌ای ندارد؟
#
# - a) تغییرپذیری
# - ✅ b) کران‌دار بودن
# - c) زمان‌گسسته بودن
# - d) غیرخطی بودن
#
# ---
#
# ### 19. تابع $$( x[n] = \cos(n\pi) )$$ چه نوع سیگنالی است؟
#
# - a) DC
# - ✅ b) متناوب با دوره ۲
# - c) پله‌ای
# - d) نمایی
#
# ---
#
# ### 20. برای یک سیستم زمان‌ناور، اگر ورودی به اندازه ۲ واحد به عقب برود، خروجی باید:
#
# - a) تغییری نکند
# - ✅ b) دقیقاً ۲ واحد عقب بیفتد
# - c) ناپایدار شود
# - d) مشتق‌گیری شود
